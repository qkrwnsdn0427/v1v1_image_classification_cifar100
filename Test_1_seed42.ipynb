# %%
from __future__ import print_function
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import config as cf

import torchvision
import torchvision.transforms as transforms

import os
import sys
import time
import argparse
import datetime

from wide_resnet import *  # Wide_resnet.py
from torch.autograd import Variable
from torch.utils.data import ConcatDataset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import os

os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
parser = argparse.ArgumentParser(description='PyTorch CIFAR-10 Training')
parser.add_argument('--lr', default=0.1, type=float, help='learning_rate')
parser.add_argument('--seed', default=42, type=int, help='seed')
parser.add_argument('--net_type', default='wide-resnet', type=str, help='model')
parser.add_argument('--depth', default=28, type=int, help='depth of model')
parser.add_argument('--widen_factor_1', default=14, type=int, help='width of model')
parser.add_argument('--widen_factor_2', default=16, type=int, help='width of model')
parser.add_argument('--widen_factor_3', default=18, type=int, help='width of model')
parser.add_argument('--dropout', default=0.2, type=float, help='dropout_rate')
parser.add_argument('--dataset', default='cifar100', type=str, help='dataset = cifar100')
parser.add_argument('--resume', '-r', action='store_true', help='resume from checkpoint')
parser.add_argument('--testOnly', '-t', action='store_true', help='Test mode with the saved model')
args = parser.parse_args(args=[])

# Seed setup
seed = args.seed
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True)

def map_to_superclass(labels, class_to_superclass):
    return [class_to_superclass[label] for label in labels]

def seed_worker(worker_id):
    np.random.seed(seed + worker_id)
    random.seed(seed + worker_id)

# Hyperparameter settings
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
best_acc = 0
start_epoch, num_epochs, batch_size, optim_type = cf.start_epoch, cf.num_epochs, cf.batch_size, cf.optim_type

train_losses = []  # List to store training losses
test_losses = []   # List to store test losses

# Data Upload
print('\n[Phase 1] : Data Preparation')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(cf.mean[args.dataset], cf.std[args.dataset]),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cf.mean[args.dataset], cf.std[args.dataset]),
])

print("| Preparing CIFAR-100 dataset...")
sys.stdout.write("| ")
trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=False, transform=transform_test)
num_classes = 100

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=8, worker_init_fn=seed_worker)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=8)

# CIFAR-100 Superclass mapping (index-based)
superclass_mapping = {
    0: [4, 30, 55, 72, 95],  # aquatic mammals
    1: [1, 32, 67, 73, 91],  # fish
    2: [54, 62, 70, 82, 92],  # flowers
    3: [9, 10, 16, 28, 61],  # food containers
    4: [0, 51, 53, 57, 83],  # fruit and vegetables
    5: [22, 39, 40, 86, 87],  # household electrical devices
    6: [5, 20, 25, 84, 94],  # household furniture
    7: [6, 7, 14, 18, 24],   # insects
    8: [3, 42, 43, 88, 97],  # large carnivores
    9: [12, 17, 37, 68, 76],  # large man-made outdoor things
    10: [23, 33, 49, 60, 71],  # large natural outdoor scenes
    11: [15, 19, 21, 31, 38],  # large omnivores and herbivores
    12: [34, 63, 64, 66, 75],  # medium-sized mammals
    13: [26, 45, 77, 79, 99],  # non-insect invertebrates
    14: [2, 11, 35, 46, 98],  # people
    15: [27, 29, 44, 78, 93],  # reptiles
    16: [36, 50, 65, 74, 80],  # small mammals
    17: [47, 52, 56, 59, 96],  # trees
    18: [8, 13, 48, 58, 90],  # vehicles 1
    19: [41, 69, 81, 85, 89],  # vehicles 2
}

# Create a list to store which superclass each class belongs to
class_to_superclass = [None] * 100
for super_idx, class_indices in superclass_mapping.items():
    for class_idx in class_indices:
        class_to_superclass[class_idx] = super_idx

# CutMix function
def cutmix_data(x, y, beta=1.0):
    if beta > 0:
        lam = np.random.beta(beta, beta)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size).cuda()

    y_a, y_b = y, y[index]

    bbx1, bby1, bbx2, bby2 = rand_bbox(x.size(), lam)
    x[:, :, bbx1:bbx2, bby1:bby2] = x[index, :, bbx1:bbx2, bby1:bby2]

    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (x.size()[-1] * x.size()[-2]))
    
    return x, y_a, y_b, lam

# Random box function for CutMix
def rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = int(W * cut_rat)
    cut_h = int(H * cut_rat)

    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2

# Return Wide-ResNet network and filename
def get_ensemble_networks(args):
    net1 = Wide_ResNet(args.depth, args.widen_factor_1, args.dropout, num_classes)
    net2 = Wide_ResNet(args.depth, args.widen_factor_2, args.dropout, num_classes)
    net3 = Wide_ResNet(args.depth, args.widen_factor_3, args.dropout, num_classes)
    file_name1 = 'wide-resnet1-'+str(args.depth)+'x'+str(args.widen_factor_1)
    file_name2 = 'wide-resnet2-'+str(args.depth)+'x'+str(args.widen_factor_2)
    file_name3 = 'wide-resnet3-'+str(args.depth)+'x'+str(args.widen_factor_3)
    return [net1, net2, net3], [file_name1, file_name2, file_name3]


# Model setup
print('\n[Phase 2] : Model setup for Hard Voting Ensemble')
print('| Building net types for ensemble...')
nets, file_names = get_ensemble_networks(args)
for net in nets:
    net.apply(conv_init)

if use_cuda:
    for i, net in enumerate(nets):
        nets[i] = torch.nn.DataParallel(net, device_ids=range(torch.cuda.device_count()))
        nets[i].cuda()
    cudnn.benchmark = True


if use_cuda:
    for i, net in enumerate(nets):
        nets[i] = torch.nn.DataParallel(net, device_ids=range(torch.cuda.device_count()))
        nets[i].cuda()
    cudnn.benchmark = True

criterion = nn.CrossEntropyLoss()

# Hard Voting Prediction
def hard_voting_prediction(outputs_list):
    """Performs hard voting by choosing the most common prediction."""
    outputs_stack = torch.stack(outputs_list)  # Stack outputs from all models
    voted_predictions, _ = torch.mode(outputs_stack, dim=0)  # Hard voting
    return voted_predictions

# Training function
def train(epoch):
    
    optimizers = [optim.SGD(net.parameters(), lr=cf.learning_rate(args.lr, epoch), momentum=0.9, weight_decay=5e-4) for net in nets]
    
    for net in nets:
        net.train()

    train_loss = 0
    correct = 0
    total = 0
    
    print('\n=> Training Epoch #%d, LR=%.4f' %(epoch, cf.learning_rate(args.lr, epoch)))
    
    for batch_idx, (inputs, targets) in enumerate(trainloader):
        if use_cuda:
            inputs, targets = inputs.cuda(), targets.cuda()

        inputs, targets = Variable(inputs), Variable(targets)
        inputs, targets_a, targets_b, lam = cutmix_data(inputs, targets, beta=1.0)
        
        
        for i, net in enumerate(nets):
            optimizers[i].zero_grad()
            outputs = net(inputs) 
            loss = lam * criterion(outputs, targets_a) + (1 - lam) * criterion(outputs, targets_b)
            loss.backward() 
            optimizers[i].step()  

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)
        correct += predicted.eq(targets.data).cpu().sum()

        sys.stdout.write('\r')
        sys.stdout.write('| Epoch [%3d/%3d] Iter[%3d/%3d]\t\tLoss: %.4f Acc@1: %.3f%%'
                         % (epoch, num_epochs, batch_idx+1,
                            (len(trainset)//batch_size)+1, loss.item(), 100.*correct/total))
        sys.stdout.flush()

    train_loss = train_loss / len(trainloader)
    train_losses.append(train_loss)

best_acc = 0
best_top5_acc = 0
best_superclass_top1_acc = 0

# Test function with hard voting ensemble
def test_ensemble(epoch):
    global best_acc, best_top5_acc, best_superclass_top1_acc
    for net in nets:
        net.eval()
    test_loss = 0
    correct = 0
    total = 0
    
    correct_top1_general = 0
    correct_top5_general = 0
    correct_top1_superclass = 0
    correct_top5_superclass = 0
    
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            if use_cuda:
                inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = Variable(inputs), Variable(targets)

            # Get outputs from all models
            outputs_list = [net(inputs) for net in nets]

            # Hard voting for Top-1 predictions
            outputs_avg = sum(outputs_list) / len(outputs_list)  # Average logits for top-5 
            top5_pred = torch.topk(outputs_avg, 5, dim=1)[1]  # General top-5 prediction
            voted_top1 = hard_voting_prediction([torch.argmax(out, dim=1) for out in outputs_list])

            total += targets.size(0)
            correct += voted_top1.eq(targets.data).cpu().sum()

            correct_top1_general += voted_top1.eq(targets.data).cpu().sum()
            correct_top5_general += sum([targets[i] in top5_pred[i] for i in range(targets.size(0))])

            # Superclass accuracy
            true_superclass = torch.tensor(map_to_superclass(targets.cpu().numpy(), class_to_superclass)).to(device)
            pred_superclasses_top1 = torch.tensor(map_to_superclass(voted_top1.cpu().numpy(), class_to_superclass)).to(device)

            correct_top1_superclass += (pred_superclasses_top1 == true_superclass).sum().item()

            pred_superclasses_top5 = [torch.tensor(map_to_superclass(pred.cpu().numpy(), class_to_superclass)).to(device) for pred in top5_pred]
            for i in range(targets.size(0)):
                true_label_superclass = true_superclass[i].item()
                if true_label_superclass in pred_superclasses_top5[i].cpu().numpy():
                    correct_top5_superclass += 1

        # Test results output
        acc_top1_general = 100. * correct_top1_general / total
        acc_top5_general = 100. * correct_top5_general / total
        acc_top1_superclass = 100. * correct_top1_superclass / total
        acc_top5_superclass = 100. * correct_top5_superclass / total

        acc = 100.*correct/total
        print(f"-----------------Ensemble Model----------------------")
        print("| Validation Epoch #%d\t\t\tAcc@1: %.2f%%" %(epoch, acc))
        print(f"* General Top-1 Accuracy = {acc_top1_general:.2f}%")
        print(f"* General Top-5 Accuracy = {acc_top5_general:.2f}%")
        print(f"* Superclass Top-1 Accuracy = {acc_top1_superclass:.2f}%")
        print(f"* Superclass Top-5 Accuracy = {acc_top5_superclass:.2f}%")

        checkpoint_dir = './checkpoint/' + args.dataset + os.sep
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)
        
        # Save model if best accuracy is achieved for each metric
        if acc > best_acc:
            best_acc = acc
            print('| Updating Best Top-1 model...\t\t\tAcc@1 = %.2f%%' % (acc))
            torch.save({
                'net': nets,
                'acc': best_acc,
                'epoch': epoch,
            }, checkpoint_dir + 'best_top1_model.pth')
        
        if acc_top5_general > best_top5_acc:
            best_top5_acc = acc_top5_general
            print('| Updating Best Top-5 model...\t\t\tAcc@5 = %.2f%%' % (acc_top5_general))
            torch.save({
                'net': nets,
                'acc': best_top5_acc,
                'epoch': epoch,
            }, checkpoint_dir + 'best_top5_model.pth')
        
        if acc_top1_superclass > best_superclass_top1_acc:
            best_superclass_top1_acc = acc_top1_superclass
            print('| Updating Best Superclass Top-1 model...\t\t\tAcc@1 Superclass = %.2f%%' % (acc_top1_superclass))
            torch.save({
                'net': nets,
                'acc': best_superclass_top1_acc,
                'epoch': epoch,
            }, checkpoint_dir + 'best_superclass_top1_model.pth')
        
    return acc_top1_general, acc_top5_general, acc_top1_superclass, acc_top5_superclass

# Main training and testing loop
if not args.testOnly:
    elapsed_time = 0
    for epoch in range(start_epoch, num_epochs):
        start_time = time.time()

        train(epoch)
        test_ensemble(epoch)

        epoch_time = time.time() - start_time
        elapsed_time += epoch_time
        print(f'| Elapsed time: {int(elapsed_time//3600)}:{int((elapsed_time % 3600)//60)}:{int(elapsed_time % 60)}')

# Final testing with ensemble after all epochs
print('\n[Phase 4] : Testing model ensemble')
top1_acc, top5_acc, top1_superclass_acc, top5_superclass_acc = test_ensemble(cf.num_epochs)
print(f'* Final Test results : Best Acc@1 = {best_acc:.2f}%, Best Acc@5 = {best_top5_acc:.2f}%, Best Superclass Acc@1 = {best_superclass_top1_acc:.2f}%')

# Visualizing the training vs test loss
plt.plot(train_losses, label='Training Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training vs Test Loss')
plt.show()
# Out:
# [Phase 1] : Data Preparation
# | Preparing CIFAR-100 dataset...
# | Files already downloaded and verified
#
# [Phase 2] : Model setup for Hard Voting Ensemble
# | Building net types for ensemble...
# | Wide-Resnet 28x14
# | Wide-Resnet 28x16
# | Wide-Resnet 28x18
#
# => Training Epoch #1, LR=0.1000
# | Epoch [  1/ 95] Iter[391/391]		Loss: 4.1062 Acc@1: 5.446%-----------------Ensemble Model----------------------
# | Validation Epoch #1			Acc@1: 9.70%
# * General Top-1 Accuracy = 9.70%
# * General Top-5 Accuracy = 32.01%
# * Superclass Top-1 Accuracy = 22.23%
# * Superclass Top-5 Accuracy = 51.35%
# | Updating Best Top-1 model...			Acc@1 = 9.70%
# | Updating Best Top-5 model...			Acc@5 = 32.01%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 22.23%
# | Elapsed time: 0:13:17
#
# => Training Epoch #2, LR=0.1000
# | Epoch [  2/ 95] Iter[391/391]		Loss: 4.0285 Acc@1: 9.610%%-----------------Ensemble Model----------------------
# | Validation Epoch #2			Acc@1: 12.84%
# * General Top-1 Accuracy = 12.84%
# * General Top-5 Accuracy = 36.62%
# * Superclass Top-1 Accuracy = 24.01%
# * Superclass Top-5 Accuracy = 55.78%
# | Updating Best Top-1 model...			Acc@1 = 12.84%
# | Updating Best Top-5 model...			Acc@5 = 36.62%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 24.01%
# | Elapsed time: 0:27:58
#
# => Training Epoch #3, LR=0.1000
# | Epoch [  3/ 95] Iter[391/391]		Loss: 3.2314 Acc@1: 13.306%-----------------Ensemble Model----------------------
# | Validation Epoch #3			Acc@1: 17.28%
# * General Top-1 Accuracy = 17.28%
# * General Top-5 Accuracy = 44.31%
# * Superclass Top-1 Accuracy = 29.72%
# * Superclass Top-5 Accuracy = 61.54%
# | Updating Best Top-1 model...			Acc@1 = 17.28%
# | Updating Best Top-5 model...			Acc@5 = 44.31%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 29.72%
# | Elapsed time: 0:42:41
#
# => Training Epoch #4, LR=0.1000
# | Epoch [  4/ 95] Iter[391/391]		Loss: 3.1476 Acc@1: 17.556%-----------------Ensemble Model----------------------
# | Validation Epoch #4			Acc@1: 20.81%
# * General Top-1 Accuracy = 20.81%
# * General Top-5 Accuracy = 51.86%
# * Superclass Top-1 Accuracy = 34.60%
# * Superclass Top-5 Accuracy = 66.38%
# | Updating Best Top-1 model...			Acc@1 = 20.81%
# | Updating Best Top-5 model...			Acc@5 = 51.86%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 34.60%
# | Elapsed time: 0:57:17
#
# => Training Epoch #5, LR=0.1000
# | Epoch [  5/ 95] Iter[391/391]		Loss: 3.7548 Acc@1: 20.336%-----------------Ensemble Model----------------------
# | Validation Epoch #5			Acc@1: 27.20%
# * General Top-1 Accuracy = 27.20%
# * General Top-5 Accuracy = 60.24%
# * Superclass Top-1 Accuracy = 40.27%
# * Superclass Top-5 Accuracy = 73.34%
# | Updating Best Top-1 model...			Acc@1 = 27.20%
# | Updating Best Top-5 model...			Acc@5 = 60.24%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 40.27%
# | Elapsed time: 1:11:55
#
# => Training Epoch #6, LR=0.1000
# | Epoch [  6/ 95] Iter[391/391]		Loss: 2.7246 Acc@1: 22.970%-----------------Ensemble Model----------------------
# | Validation Epoch #6			Acc@1: 31.96%
# * General Top-1 Accuracy = 31.96%
# * General Top-5 Accuracy = 65.63%
# * Superclass Top-1 Accuracy = 45.85%
# * Superclass Top-5 Accuracy = 78.17%
# | Updating Best Top-1 model...			Acc@1 = 31.96%
# | Updating Best Top-5 model...			Acc@5 = 65.63%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 45.85%
# | Elapsed time: 1:26:30
#
# => Training Epoch #7, LR=0.1000
# | Epoch [  7/ 95] Iter[391/391]		Loss: 2.7976 Acc@1: 25.326%-----------------Ensemble Model----------------------
# | Validation Epoch #7			Acc@1: 30.81%
# * General Top-1 Accuracy = 30.81%
# * General Top-5 Accuracy = 64.30%
# * Superclass Top-1 Accuracy = 44.42%
# * Superclass Top-5 Accuracy = 76.36%
# | Elapsed time: 1:41:7
#
# => Training Epoch #8, LR=0.1000
# | Epoch [  8/ 95] Iter[391/391]		Loss: 3.3103 Acc@1: 27.022%-----------------Ensemble Model----------------------
# | Validation Epoch #8			Acc@1: 29.57%
# * General Top-1 Accuracy = 29.57%
# * General Top-5 Accuracy = 63.63%
# * Superclass Top-1 Accuracy = 42.18%
# * Superclass Top-5 Accuracy = 74.43%
# | Elapsed time: 1:55:54
#
# => Training Epoch #9, LR=0.1000
# | Epoch [  9/ 95] Iter[391/391]		Loss: 3.3984 Acc@1: 27.428%-----------------Ensemble Model----------------------
# | Validation Epoch #9			Acc@1: 41.31%
# * General Top-1 Accuracy = 41.31%
# * General Top-5 Accuracy = 75.77%
# * Superclass Top-1 Accuracy = 55.93%
# * Superclass Top-5 Accuracy = 85.26%
# | Updating Best Top-1 model...			Acc@1 = 41.31%
# | Updating Best Top-5 model...			Acc@5 = 75.77%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 55.93%
# | Elapsed time: 2:10:46
#
# => Training Epoch #10, LR=0.1000
# | Epoch [ 10/ 95] Iter[391/391]		Loss: 2.7129 Acc@1: 30.318%-----------------Ensemble Model----------------------
# | Validation Epoch #10			Acc@1: 40.91%
# * General Top-1 Accuracy = 40.91%
# * General Top-5 Accuracy = 76.24%
# * Superclass Top-1 Accuracy = 56.23%
# * Superclass Top-5 Accuracy = 85.12%
# | Updating Best Top-5 model...			Acc@5 = 76.24%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 56.23%
# | Elapsed time: 2:25:30
#
# => Training Epoch #11, LR=0.1000
# | Epoch [ 11/ 95] Iter[391/391]		Loss: 3.0939 Acc@1: 31.686%-----------------Ensemble Model----------------------
# | Validation Epoch #11			Acc@1: 36.59%
# * General Top-1 Accuracy = 36.59%
# * General Top-5 Accuracy = 69.39%
# * Superclass Top-1 Accuracy = 49.73%
# * Superclass Top-5 Accuracy = 79.84%
# | Elapsed time: 2:40:12
#
# => Training Epoch #12, LR=0.1000
# | Epoch [ 12/ 95] Iter[391/391]		Loss: 2.4115 Acc@1: 32.504%-----------------Ensemble Model----------------------
# | Validation Epoch #12			Acc@1: 46.34%
# * General Top-1 Accuracy = 46.34%
# * General Top-5 Accuracy = 79.49%
# * Superclass Top-1 Accuracy = 61.36%
# * Superclass Top-5 Accuracy = 87.50%
# | Updating Best Top-1 model...			Acc@1 = 46.34%
# | Updating Best Top-5 model...			Acc@5 = 79.49%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 61.36%
# | Elapsed time: 2:55:1
#
# => Training Epoch #13, LR=0.1000
# | Epoch [ 13/ 95] Iter[391/391]		Loss: 2.2890 Acc@1: 33.962%-----------------Ensemble Model----------------------
# | Validation Epoch #13			Acc@1: 40.49%
# * General Top-1 Accuracy = 40.49%
# * General Top-5 Accuracy = 73.26%
# * Superclass Top-1 Accuracy = 55.17%
# * Superclass Top-5 Accuracy = 82.85%
# | Elapsed time: 3:9:51
#
# => Training Epoch #14, LR=0.1000
# | Epoch [ 14/ 95] Iter[391/391]		Loss: 1.9799 Acc@1: 34.216%-----------------Ensemble Model----------------------
# | Validation Epoch #14			Acc@1: 49.38%
# * General Top-1 Accuracy = 49.38%
# * General Top-5 Accuracy = 81.30%
# * Superclass Top-1 Accuracy = 63.08%
# * Superclass Top-5 Accuracy = 87.95%
# | Updating Best Top-1 model...			Acc@1 = 49.38%
# | Updating Best Top-5 model...			Acc@5 = 81.30%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 63.08%
# | Elapsed time: 3:24:48
#
# => Training Epoch #15, LR=0.1000
# | Epoch [ 15/ 95] Iter[391/391]		Loss: 2.7057 Acc@1: 36.702%-----------------Ensemble Model----------------------
# | Validation Epoch #15			Acc@1: 49.64%
# * General Top-1 Accuracy = 49.64%
# * General Top-5 Accuracy = 82.36%
# * Superclass Top-1 Accuracy = 63.40%
# * Superclass Top-5 Accuracy = 89.21%
# | Updating Best Top-1 model...			Acc@1 = 49.64%
# | Updating Best Top-5 model...			Acc@5 = 82.36%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 63.40%
# | Elapsed time: 3:39:34
#
# => Training Epoch #16, LR=0.1000
# | Epoch [ 16/ 95] Iter[391/391]		Loss: 2.8989 Acc@1: 37.128%-----------------Ensemble Model----------------------
# | Validation Epoch #16			Acc@1: 49.59%
# * General Top-1 Accuracy = 49.59%
# * General Top-5 Accuracy = 82.16%
# * Superclass Top-1 Accuracy = 64.41%
# * Superclass Top-5 Accuracy = 89.25%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 64.41%
# | Elapsed time: 3:54:12
#
# => Training Epoch #17, LR=0.1000
# | Epoch [ 17/ 95] Iter[391/391]		Loss: 3.0291 Acc@1: 38.644%-----------------Ensemble Model----------------------
# | Validation Epoch #17			Acc@1: 49.78%
# * General Top-1 Accuracy = 49.78%
# * General Top-5 Accuracy = 80.05%
# * Superclass Top-1 Accuracy = 62.33%
# * Superclass Top-5 Accuracy = 87.26%
# | Updating Best Top-1 model...			Acc@1 = 49.78%
# | Elapsed time: 4:8:53
#
# => Training Epoch #18, LR=0.1000
# | Epoch [ 18/ 95] Iter[391/391]		Loss: 2.7756 Acc@1: 37.576%-----------------Ensemble Model----------------------
# | Validation Epoch #18			Acc@1: 47.12%
# * General Top-1 Accuracy = 47.12%
# * General Top-5 Accuracy = 79.12%
# * Superclass Top-1 Accuracy = 59.81%
# * Superclass Top-5 Accuracy = 87.78%
# | Elapsed time: 4:23:38
#
# => Training Epoch #19, LR=0.1000
# | Epoch [ 19/ 95] Iter[391/391]		Loss: 3.0728 Acc@1: 38.614%-----------------Ensemble Model----------------------
# | Validation Epoch #19			Acc@1: 51.60%
# * General Top-1 Accuracy = 51.60%
# * General Top-5 Accuracy = 82.11%
# * Superclass Top-1 Accuracy = 64.39%
# * Superclass Top-5 Accuracy = 88.92%
# | Updating Best Top-1 model...			Acc@1 = 51.60%
# | Elapsed time: 4:38:32
#
# => Training Epoch #20, LR=0.1000
# | Epoch [ 20/ 95] Iter[391/391]		Loss: 1.6642 Acc@1: 40.104%-----------------Ensemble Model----------------------
# | Validation Epoch #20			Acc@1: 50.20%
# * General Top-1 Accuracy = 50.20%
# * General Top-5 Accuracy = 81.71%
# * Superclass Top-1 Accuracy = 64.10%
# * Superclass Top-5 Accuracy = 89.15%
# | Elapsed time: 4:53:22
#
# => Training Epoch #21, LR=0.1000
# | Epoch [ 21/ 95] Iter[391/391]		Loss: 2.9584 Acc@1: 41.312%-----------------Ensemble Model----------------------
# | Validation Epoch #21			Acc@1: 54.54%
# * General Top-1 Accuracy = 54.54%
# * General Top-5 Accuracy = 84.11%
# * Superclass Top-1 Accuracy = 67.19%
# * Superclass Top-5 Accuracy = 90.12%
# | Updating Best Top-1 model...			Acc@1 = 54.54%
# | Updating Best Top-5 model...			Acc@5 = 84.11%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 67.19%
# | Elapsed time: 5:8:10
#
# => Training Epoch #22, LR=0.1000
# | Epoch [ 22/ 95] Iter[391/391]		Loss: 2.3909 Acc@1: 41.640%-----------------Ensemble Model----------------------
# | Validation Epoch #22			Acc@1: 55.09%
# * General Top-1 Accuracy = 55.09%
# * General Top-5 Accuracy = 86.26%
# * Superclass Top-1 Accuracy = 68.83%
# * Superclass Top-5 Accuracy = 91.48%
# | Updating Best Top-1 model...			Acc@1 = 55.09%
# | Updating Best Top-5 model...			Acc@5 = 86.26%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 68.83%
# | Elapsed time: 5:23:1
#
# => Training Epoch #23, LR=0.1000
# | Epoch [ 23/ 95] Iter[391/391]		Loss: 2.9223 Acc@1: 41.980%-----------------Ensemble Model----------------------
# | Validation Epoch #23			Acc@1: 54.80%
# * General Top-1 Accuracy = 54.80%
# * General Top-5 Accuracy = 85.93%
# * Superclass Top-1 Accuracy = 67.49%
# * Superclass Top-5 Accuracy = 91.93%
# | Elapsed time: 5:37:52
#
# => Training Epoch #24, LR=0.1000
# | Epoch [ 24/ 95] Iter[391/391]		Loss: 2.6587 Acc@1: 42.346%-----------------Ensemble Model----------------------
# | Validation Epoch #24			Acc@1: 57.52%
# * General Top-1 Accuracy = 57.52%
# * General Top-5 Accuracy = 86.34%
# * Superclass Top-1 Accuracy = 68.84%
# * Superclass Top-5 Accuracy = 91.86%
# | Updating Best Top-1 model...			Acc@1 = 57.52%
# | Updating Best Top-5 model...			Acc@5 = 86.34%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 68.84%
# | Elapsed time: 5:52:47
#
# => Training Epoch #25, LR=0.1000
# | Epoch [ 25/ 95] Iter[391/391]		Loss: 2.5857 Acc@1: 42.076%-----------------Ensemble Model----------------------
# | Validation Epoch #25			Acc@1: 52.64%
# * General Top-1 Accuracy = 52.64%
# * General Top-5 Accuracy = 82.61%
# * Superclass Top-1 Accuracy = 64.67%
# * Superclass Top-5 Accuracy = 88.74%
# | Elapsed time: 6:7:31
#
# => Training Epoch #26, LR=0.1000
# | Epoch [ 26/ 95] Iter[391/391]		Loss: 2.5238 Acc@1: 43.582%-----------------Ensemble Model----------------------
# | Validation Epoch #26			Acc@1: 58.97%
# * General Top-1 Accuracy = 58.97%
# * General Top-5 Accuracy = 87.20%
# * Superclass Top-1 Accuracy = 70.60%
# * Superclass Top-5 Accuracy = 92.89%
# | Updating Best Top-1 model...			Acc@1 = 58.97%
# | Updating Best Top-5 model...			Acc@5 = 87.20%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 70.60%
# | Elapsed time: 6:22:19
#
# => Training Epoch #27, LR=0.1000
# | Epoch [ 27/ 95] Iter[391/391]		Loss: 2.7465 Acc@1: 42.376%-----------------Ensemble Model----------------------
# | Validation Epoch #27			Acc@1: 58.93%
# * General Top-1 Accuracy = 58.93%
# * General Top-5 Accuracy = 88.14%
# * Superclass Top-1 Accuracy = 71.91%
# * Superclass Top-5 Accuracy = 92.95%
# | Updating Best Top-5 model...			Acc@5 = 88.14%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 71.91%
# | Elapsed time: 6:36:59
#
# => Training Epoch #28, LR=0.1000
# | Epoch [ 28/ 95] Iter[391/391]		Loss: 2.2006 Acc@1: 44.096%-----------------Ensemble Model----------------------
# | Validation Epoch #28			Acc@1: 58.56%
# * General Top-1 Accuracy = 58.56%
# * General Top-5 Accuracy = 87.32%
# * Superclass Top-1 Accuracy = 70.46%
# * Superclass Top-5 Accuracy = 92.82%
# | Elapsed time: 6:51:36
#
# => Training Epoch #29, LR=0.1000
# | Epoch [ 29/ 95] Iter[391/391]		Loss: 2.1311 Acc@1: 43.840%-----------------Ensemble Model----------------------
# | Validation Epoch #29			Acc@1: 54.11%
# * General Top-1 Accuracy = 54.11%
# * General Top-5 Accuracy = 86.04%
# * Superclass Top-1 Accuracy = 66.70%
# * Superclass Top-5 Accuracy = 91.43%
# | Elapsed time: 7:6:12
#
# => Training Epoch #30, LR=0.1000
# | Epoch [ 30/ 95] Iter[391/391]		Loss: 2.2875 Acc@1: 42.770%-----------------Ensemble Model----------------------
# | Validation Epoch #30			Acc@1: 59.26%
# * General Top-1 Accuracy = 59.26%
# * General Top-5 Accuracy = 86.77%
# * Superclass Top-1 Accuracy = 71.02%
# * Superclass Top-5 Accuracy = 92.08%
# | Updating Best Top-1 model...			Acc@1 = 59.26%
# | Elapsed time: 7:20:57
#
# => Training Epoch #31, LR=0.0300
# | Epoch [ 31/ 95] Iter[391/391]		Loss: 2.7125 Acc@1: 51.446%-----------------Ensemble Model----------------------
# | Validation Epoch #31			Acc@1: 72.94%
# * General Top-1 Accuracy = 72.94%
# * General Top-5 Accuracy = 94.27%
# * Superclass Top-1 Accuracy = 83.23%
# * Superclass Top-5 Accuracy = 96.72%
# | Updating Best Top-1 model...			Acc@1 = 72.94%
# | Updating Best Top-5 model...			Acc@5 = 94.27%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 83.23%
# | Elapsed time: 7:35:43
#
# => Training Epoch #32, LR=0.0300
# | Epoch [ 32/ 95] Iter[391/391]		Loss: 2.2748 Acc@1: 54.724%-----------------Ensemble Model----------------------
# | Validation Epoch #32			Acc@1: 73.47%
# * General Top-1 Accuracy = 73.47%
# * General Top-5 Accuracy = 94.02%
# * Superclass Top-1 Accuracy = 83.59%
# * Superclass Top-5 Accuracy = 96.56%
# | Updating Best Top-1 model...			Acc@1 = 73.47%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 83.59%
# | Elapsed time: 7:50:20
#
# => Training Epoch #33, LR=0.0300
# | Epoch [ 33/ 95] Iter[391/391]		Loss: 2.0658 Acc@1: 55.418%-----------------Ensemble Model----------------------
# | Validation Epoch #33			Acc@1: 73.26%
# * General Top-1 Accuracy = 73.26%
# * General Top-5 Accuracy = 93.85%
# * Superclass Top-1 Accuracy = 83.29%
# * Superclass Top-5 Accuracy = 96.76%
# | Elapsed time: 8:4:59
#
# => Training Epoch #34, LR=0.0300
# | Epoch [ 34/ 95] Iter[391/391]		Loss: 2.4643 Acc@1: 54.552%-----------------Ensemble Model----------------------
# | Validation Epoch #34			Acc@1: 71.55%
# * General Top-1 Accuracy = 71.55%
# * General Top-5 Accuracy = 93.45%
# * Superclass Top-1 Accuracy = 82.14%
# * Superclass Top-5 Accuracy = 96.20%
# | Elapsed time: 8:19:37
#
# => Training Epoch #35, LR=0.0300
# | Epoch [ 35/ 95] Iter[391/391]		Loss: 2.5070 Acc@1: 54.252%-----------------Ensemble Model----------------------
# | Validation Epoch #35			Acc@1: 72.58%
# * General Top-1 Accuracy = 72.58%
# * General Top-5 Accuracy = 93.81%
# * Superclass Top-1 Accuracy = 83.58%
# * Superclass Top-5 Accuracy = 96.45%
# | Elapsed time: 8:34:15
#
# => Training Epoch #36, LR=0.0300
# | Epoch [ 36/ 95] Iter[391/391]		Loss: 2.6869 Acc@1: 56.120%-----------------Ensemble Model----------------------
# | Validation Epoch #36			Acc@1: 73.33%
# * General Top-1 Accuracy = 73.33%
# * General Top-5 Accuracy = 93.97%
# * Superclass Top-1 Accuracy = 83.36%
# * Superclass Top-5 Accuracy = 96.75%
# | Elapsed time: 8:48:52
#
# => Training Epoch #37, LR=0.0300
# | Epoch [ 37/ 95] Iter[391/391]		Loss: 2.4271 Acc@1: 55.262%-----------------Ensemble Model----------------------
# | Validation Epoch #37			Acc@1: 71.86%
# * General Top-1 Accuracy = 71.86%
# * General Top-5 Accuracy = 93.44%
# * Superclass Top-1 Accuracy = 82.10%
# * Superclass Top-5 Accuracy = 96.38%
# | Elapsed time: 9:3:29
#
# => Training Epoch #38, LR=0.0300
# | Epoch [ 38/ 95] Iter[391/391]		Loss: 2.0003 Acc@1: 56.646%-----------------Ensemble Model----------------------
# | Validation Epoch #38			Acc@1: 73.69%
# * General Top-1 Accuracy = 73.69%
# * General Top-5 Accuracy = 94.15%
# * Superclass Top-1 Accuracy = 83.48%
# * Superclass Top-5 Accuracy = 96.71%
# | Updating Best Top-1 model...			Acc@1 = 73.69%
# | Elapsed time: 9:18:11
#
# => Training Epoch #39, LR=0.0300
# | Epoch [ 39/ 95] Iter[391/391]		Loss: 2.3024 Acc@1: 56.124%-----------------Ensemble Model----------------------
# | Validation Epoch #39			Acc@1: 72.54%
# * General Top-1 Accuracy = 72.54%
# * General Top-5 Accuracy = 93.74%
# * Superclass Top-1 Accuracy = 82.31%
# * Superclass Top-5 Accuracy = 96.48%
# | Elapsed time: 9:32:49
#
# => Training Epoch #40, LR=0.0300
# | Epoch [ 40/ 95] Iter[391/391]		Loss: 1.4992 Acc@1: 56.214%-----------------Ensemble Model----------------------
# | Validation Epoch #40			Acc@1: 73.55%
# * General Top-1 Accuracy = 73.55%
# * General Top-5 Accuracy = 94.61%
# * Superclass Top-1 Accuracy = 83.99%
# * Superclass Top-5 Accuracy = 96.94%
# | Updating Best Top-5 model...			Acc@5 = 94.61%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 83.99%
# | Elapsed time: 9:47:31
#
# => Training Epoch #41, LR=0.0300
# | Epoch [ 41/ 95] Iter[391/391]		Loss: 1.1011 Acc@1: 56.582%-----------------Ensemble Model----------------------
# | Validation Epoch #41			Acc@1: 72.87%
# * General Top-1 Accuracy = 72.87%
# * General Top-5 Accuracy = 94.64%
# * Superclass Top-1 Accuracy = 82.84%
# * Superclass Top-5 Accuracy = 96.93%
# | Updating Best Top-5 model...			Acc@5 = 94.64%
# | Elapsed time: 10:2:4
#
# => Training Epoch #42, LR=0.0300
# | Epoch [ 42/ 95] Iter[391/391]		Loss: 2.2641 Acc@1: 58.068%-----------------Ensemble Model----------------------
# | Validation Epoch #42			Acc@1: 72.30%
# * General Top-1 Accuracy = 72.30%
# * General Top-5 Accuracy = 93.57%
# * Superclass Top-1 Accuracy = 82.28%
# * Superclass Top-5 Accuracy = 96.20%
# | Elapsed time: 10:16:38
#
# => Training Epoch #43, LR=0.0300
# | Epoch [ 43/ 95] Iter[391/391]		Loss: 2.3337 Acc@1: 54.894%-----------------Ensemble Model----------------------
# | Validation Epoch #43			Acc@1: 73.13%
# * General Top-1 Accuracy = 73.13%
# * General Top-5 Accuracy = 93.88%
# * Superclass Top-1 Accuracy = 83.53%
# * Superclass Top-5 Accuracy = 96.63%
# | Elapsed time: 10:31:14
#
# => Training Epoch #44, LR=0.0300
# | Epoch [ 44/ 95] Iter[391/391]		Loss: 1.8889 Acc@1: 58.644%-----------------Ensemble Model----------------------
# | Validation Epoch #44			Acc@1: 73.21%
# * General Top-1 Accuracy = 73.21%
# * General Top-5 Accuracy = 93.95%
# * Superclass Top-1 Accuracy = 83.12%
# * Superclass Top-5 Accuracy = 96.68%
# | Elapsed time: 10:45:52
#
# => Training Epoch #45, LR=0.0300
# | Epoch [ 45/ 95] Iter[391/391]		Loss: 2.0795 Acc@1: 56.344%-----------------Ensemble Model----------------------
# | Validation Epoch #45			Acc@1: 72.82%
# * General Top-1 Accuracy = 72.82%
# * General Top-5 Accuracy = 94.33%
# * Superclass Top-1 Accuracy = 83.48%
# * Superclass Top-5 Accuracy = 97.05%
# | Elapsed time: 11:0:40
#
# => Training Epoch #46, LR=0.0300
# | Epoch [ 46/ 95] Iter[391/391]		Loss: 1.1963 Acc@1: 54.684%-----------------Ensemble Model----------------------
# | Validation Epoch #46			Acc@1: 74.94%
# * General Top-1 Accuracy = 74.94%
# * General Top-5 Accuracy = 94.62%
# * Superclass Top-1 Accuracy = 84.22%
# * Superclass Top-5 Accuracy = 97.08%
# | Updating Best Top-1 model...			Acc@1 = 74.94%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 84.22%
# | Elapsed time: 11:15:22
#
# => Training Epoch #47, LR=0.0300
# | Epoch [ 47/ 95] Iter[391/391]		Loss: 0.9895 Acc@1: 57.080%-----------------Ensemble Model----------------------
# | Validation Epoch #47			Acc@1: 74.58%
# * General Top-1 Accuracy = 74.58%
# * General Top-5 Accuracy = 94.38%
# * Superclass Top-1 Accuracy = 83.82%
# * Superclass Top-5 Accuracy = 96.69%
# | Elapsed time: 11:29:58
#
# => Training Epoch #48, LR=0.0300
# | Epoch [ 48/ 95] Iter[391/391]		Loss: 2.6063 Acc@1: 55.882%-----------------Ensemble Model----------------------
# | Validation Epoch #48			Acc@1: 74.49%
# * General Top-1 Accuracy = 74.49%
# * General Top-5 Accuracy = 94.93%
# * Superclass Top-1 Accuracy = 84.40%
# * Superclass Top-5 Accuracy = 97.06%
# | Updating Best Top-5 model...			Acc@5 = 94.93%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 84.40%
# | Elapsed time: 11:44:40
#
# => Training Epoch #49, LR=0.0300
# | Epoch [ 49/ 95] Iter[391/391]		Loss: 2.2046 Acc@1: 57.212%-----------------Ensemble Model----------------------
# | Validation Epoch #49			Acc@1: 72.42%
# * General Top-1 Accuracy = 72.42%
# * General Top-5 Accuracy = 93.55%
# * Superclass Top-1 Accuracy = 82.10%
# * Superclass Top-5 Accuracy = 96.08%
# | Elapsed time: 11:59:13
#
# => Training Epoch #50, LR=0.0300
# | Epoch [ 50/ 95] Iter[391/391]		Loss: 2.8546 Acc@1: 58.080%-----------------Ensemble Model----------------------
# | Validation Epoch #50			Acc@1: 73.48%
# * General Top-1 Accuracy = 73.48%
# * General Top-5 Accuracy = 94.19%
# * Superclass Top-1 Accuracy = 83.29%
# * Superclass Top-5 Accuracy = 96.86%
# | Elapsed time: 12:13:52
#
# => Training Epoch #51, LR=0.0300
# | Epoch [ 51/ 95] Iter[391/391]		Loss: 1.5010 Acc@1: 57.414%-----------------Ensemble Model----------------------
# | Validation Epoch #51			Acc@1: 74.45%
# * General Top-1 Accuracy = 74.45%
# * General Top-5 Accuracy = 94.70%
# * Superclass Top-1 Accuracy = 84.38%
# * Superclass Top-5 Accuracy = 96.99%
# | Elapsed time: 12:28:31
#
# => Training Epoch #52, LR=0.0300
# | Epoch [ 52/ 95] Iter[391/391]		Loss: 2.5368 Acc@1: 58.306%-----------------Ensemble Model----------------------
# | Validation Epoch #52			Acc@1: 74.45%
# * General Top-1 Accuracy = 74.45%
# * General Top-5 Accuracy = 94.88%
# * Superclass Top-1 Accuracy = 84.36%
# * Superclass Top-5 Accuracy = 97.00%
# | Elapsed time: 12:43:4
#
# => Training Epoch #53, LR=0.0300
# | Epoch [ 53/ 95] Iter[391/391]		Loss: 1.5447 Acc@1: 58.714%-----------------Ensemble Model----------------------
# | Validation Epoch #53			Acc@1: 74.53%
# * General Top-1 Accuracy = 74.53%
# * General Top-5 Accuracy = 94.82%
# * Superclass Top-1 Accuracy = 84.27%
# * Superclass Top-5 Accuracy = 97.22%
# | Elapsed time: 12:57:37
#
# => Training Epoch #54, LR=0.0300
# | Epoch [ 54/ 95] Iter[391/391]		Loss: 1.3060 Acc@1: 58.072%-----------------Ensemble Model----------------------
# | Validation Epoch #54			Acc@1: 73.34%
# * General Top-1 Accuracy = 73.34%
# * General Top-5 Accuracy = 94.45%
# * Superclass Top-1 Accuracy = 83.35%
# * Superclass Top-5 Accuracy = 97.12%
# | Elapsed time: 13:12:17
#
# => Training Epoch #55, LR=0.0300
# | Epoch [ 55/ 95] Iter[391/391]		Loss: 1.5824 Acc@1: 59.078%-----------------Ensemble Model----------------------
# | Validation Epoch #55			Acc@1: 72.52%
# * General Top-1 Accuracy = 72.52%
# * General Top-5 Accuracy = 93.96%
# * Superclass Top-1 Accuracy = 83.15%
# * Superclass Top-5 Accuracy = 96.71%
# | Elapsed time: 13:26:50
#
# => Training Epoch #56, LR=0.0300
# | Epoch [ 56/ 95] Iter[391/391]		Loss: 2.2877 Acc@1: 59.820%-----------------Ensemble Model----------------------
# | Validation Epoch #56			Acc@1: 74.18%
# * General Top-1 Accuracy = 74.18%
# * General Top-5 Accuracy = 94.61%
# * Superclass Top-1 Accuracy = 83.67%
# * Superclass Top-5 Accuracy = 96.93%
# | Elapsed time: 13:41:38
#
# => Training Epoch #57, LR=0.0300
# | Epoch [ 57/ 95] Iter[391/391]		Loss: 0.9737 Acc@1: 59.558%-----------------Ensemble Model----------------------
# | Validation Epoch #57			Acc@1: 74.53%
# * General Top-1 Accuracy = 74.53%
# * General Top-5 Accuracy = 94.57%
# * Superclass Top-1 Accuracy = 83.88%
# * Superclass Top-5 Accuracy = 97.08%
# | Elapsed time: 13:56:31
#
# => Training Epoch #58, LR=0.0300
# | Epoch [ 58/ 95] Iter[391/391]		Loss: 1.8852 Acc@1: 60.198%-----------------Ensemble Model----------------------
# | Validation Epoch #58			Acc@1: 73.56%
# * General Top-1 Accuracy = 73.56%
# * General Top-5 Accuracy = 94.47%
# * Superclass Top-1 Accuracy = 83.92%
# * Superclass Top-5 Accuracy = 97.07%
# | Elapsed time: 14:11:16
#
# => Training Epoch #59, LR=0.0300
# | Epoch [ 59/ 95] Iter[391/391]		Loss: 1.7129 Acc@1: 59.068%-----------------Ensemble Model----------------------
# | Validation Epoch #59			Acc@1: 75.35%
# * General Top-1 Accuracy = 75.35%
# * General Top-5 Accuracy = 94.95%
# * Superclass Top-1 Accuracy = 85.10%
# * Superclass Top-5 Accuracy = 97.38%
# | Updating Best Top-1 model...			Acc@1 = 75.35%
# | Updating Best Top-5 model...			Acc@5 = 94.95%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 85.10%
# | Elapsed time: 14:26:8
#
# => Training Epoch #60, LR=0.0300
# | Epoch [ 60/ 95] Iter[391/391]		Loss: 2.4547 Acc@1: 58.990%-----------------Ensemble Model----------------------
# | Validation Epoch #60			Acc@1: 75.34%
# * General Top-1 Accuracy = 75.34%
# * General Top-5 Accuracy = 95.23%
# * Superclass Top-1 Accuracy = 85.19%
# * Superclass Top-5 Accuracy = 97.34%
# | Updating Best Top-5 model...			Acc@5 = 95.23%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 85.19%
# | Elapsed time: 14:40:51
#
# => Training Epoch #61, LR=0.0090
# | Epoch [ 61/ 95] Iter[391/391]		Loss: 1.6923 Acc@1: 66.116%-----------------Ensemble Model----------------------
# | Validation Epoch #61			Acc@1: 82.03%
# * General Top-1 Accuracy = 82.03%
# * General Top-5 Accuracy = 96.58%
# * Superclass Top-1 Accuracy = 89.65%
# * Superclass Top-5 Accuracy = 98.23%
# | Updating Best Top-1 model...			Acc@1 = 82.03%
# | Updating Best Top-5 model...			Acc@5 = 96.58%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 89.65%
# | Elapsed time: 14:55:37
#
# => Training Epoch #62, LR=0.0090
# | Epoch [ 62/ 95] Iter[391/391]		Loss: 0.9501 Acc@1: 66.722%-----------------Ensemble Model----------------------
# | Validation Epoch #62			Acc@1: 82.01%
# * General Top-1 Accuracy = 82.01%
# * General Top-5 Accuracy = 96.77%
# * Superclass Top-1 Accuracy = 89.81%
# * Superclass Top-5 Accuracy = 98.17%
# | Updating Best Top-5 model...			Acc@5 = 96.77%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 89.81%
# | Elapsed time: 15:10:23
#
# => Training Epoch #63, LR=0.0090
# | Epoch [ 63/ 95] Iter[391/391]		Loss: 1.6137 Acc@1: 69.052%-----------------Ensemble Model----------------------
# | Validation Epoch #63			Acc@1: 82.01%
# * General Top-1 Accuracy = 82.01%
# * General Top-5 Accuracy = 96.74%
# * Superclass Top-1 Accuracy = 89.29%
# * Superclass Top-5 Accuracy = 98.18%
# | Elapsed time: 15:25:8
#
# => Training Epoch #64, LR=0.0090
# | Epoch [ 64/ 95] Iter[391/391]		Loss: 0.9799 Acc@1: 68.462%-----------------Ensemble Model----------------------
# | Validation Epoch #64			Acc@1: 81.71%
# * General Top-1 Accuracy = 81.71%
# * General Top-5 Accuracy = 96.64%
# * Superclass Top-1 Accuracy = 89.23%
# * Superclass Top-5 Accuracy = 98.36%
# | Elapsed time: 15:39:51
#
# => Training Epoch #65, LR=0.0090
# | Epoch [ 65/ 95] Iter[391/391]		Loss: 1.2857 Acc@1: 72.634%-----------------Ensemble Model----------------------
# | Validation Epoch #65			Acc@1: 82.12%
# * General Top-1 Accuracy = 82.12%
# * General Top-5 Accuracy = 96.76%
# * Superclass Top-1 Accuracy = 89.71%
# * Superclass Top-5 Accuracy = 98.26%
# | Updating Best Top-1 model...			Acc@1 = 82.12%
# | Elapsed time: 15:54:44
#
# => Training Epoch #66, LR=0.0090
# | Epoch [ 66/ 95] Iter[391/391]		Loss: 1.1010 Acc@1: 70.670%-----------------Ensemble Model----------------------
# | Validation Epoch #66			Acc@1: 82.15%
# * General Top-1 Accuracy = 82.15%
# * General Top-5 Accuracy = 96.58%
# * Superclass Top-1 Accuracy = 89.53%
# * Superclass Top-5 Accuracy = 98.17%
# | Updating Best Top-1 model...			Acc@1 = 82.15%
# | Elapsed time: 16:9:18
#
# => Training Epoch #67, LR=0.0090
# | Epoch [ 67/ 95] Iter[391/391]		Loss: 0.2624 Acc@1: 71.078%-----------------Ensemble Model----------------------
# | Validation Epoch #67			Acc@1: 81.86%
# * General Top-1 Accuracy = 81.86%
# * General Top-5 Accuracy = 96.33%
# * Superclass Top-1 Accuracy = 89.55%
# * Superclass Top-5 Accuracy = 97.97%
# | Elapsed time: 16:23:48
#
# => Training Epoch #68, LR=0.0090
# | Epoch [ 68/ 95] Iter[391/391]		Loss: 0.4697 Acc@1: 71.490%-----------------Ensemble Model----------------------
# | Validation Epoch #68			Acc@1: 81.83%
# * General Top-1 Accuracy = 81.83%
# * General Top-5 Accuracy = 96.41%
# * Superclass Top-1 Accuracy = 89.52%
# * Superclass Top-5 Accuracy = 98.13%
# | Elapsed time: 16:38:26
#
# => Training Epoch #69, LR=0.0090
# | Epoch [ 69/ 95] Iter[391/391]		Loss: 1.7329 Acc@1: 70.510%-----------------Ensemble Model----------------------
# | Validation Epoch #69			Acc@1: 82.20%
# * General Top-1 Accuracy = 82.20%
# * General Top-5 Accuracy = 96.57%
# * Superclass Top-1 Accuracy = 89.65%
# * Superclass Top-5 Accuracy = 98.12%
# | Updating Best Top-1 model...			Acc@1 = 82.20%
# | Elapsed time: 16:53:29
#
# => Training Epoch #70, LR=0.0090
# | Epoch [ 70/ 95] Iter[391/391]		Loss: 1.8252 Acc@1: 69.276%-----------------Ensemble Model----------------------
# | Validation Epoch #70			Acc@1: 81.29%
# * General Top-1 Accuracy = 81.29%
# * General Top-5 Accuracy = 96.55%
# * Superclass Top-1 Accuracy = 89.07%
# * Superclass Top-5 Accuracy = 98.29%
# | Elapsed time: 17:8:6
#
# => Training Epoch #71, LR=0.0090
# | Epoch [ 71/ 95] Iter[391/391]		Loss: 1.4597 Acc@1: 72.762%-----------------Ensemble Model----------------------
# | Validation Epoch #71			Acc@1: 80.98%
# * General Top-1 Accuracy = 80.98%
# * General Top-5 Accuracy = 96.50%
# * Superclass Top-1 Accuracy = 89.31%
# * Superclass Top-5 Accuracy = 98.02%
# | Elapsed time: 17:22:47
#
# => Training Epoch #72, LR=0.0090
# | Epoch [ 72/ 95] Iter[391/391]		Loss: 1.0093 Acc@1: 70.034%-----------------Ensemble Model----------------------
# | Validation Epoch #72			Acc@1: 81.10%
# * General Top-1 Accuracy = 81.10%
# * General Top-5 Accuracy = 96.54%
# * Superclass Top-1 Accuracy = 88.82%
# * Superclass Top-5 Accuracy = 98.15%
# | Elapsed time: 17:37:33
#
# => Training Epoch #73, LR=0.0090
# | Epoch [ 73/ 95] Iter[391/391]		Loss: 1.6350 Acc@1: 72.856%-----------------Ensemble Model----------------------
# | Validation Epoch #73			Acc@1: 80.96%
# * General Top-1 Accuracy = 80.96%
# * General Top-5 Accuracy = 96.42%
# * Superclass Top-1 Accuracy = 88.66%
# * Superclass Top-5 Accuracy = 98.15%
# | Elapsed time: 17:52:12
#
# => Training Epoch #74, LR=0.0090
# | Epoch [ 74/ 95] Iter[391/391]		Loss: 1.6488 Acc@1: 70.234%-----------------Ensemble Model----------------------
# | Validation Epoch #74			Acc@1: 80.95%
# * General Top-1 Accuracy = 80.95%
# * General Top-5 Accuracy = 96.35%
# * Superclass Top-1 Accuracy = 88.63%
# * Superclass Top-5 Accuracy = 97.96%
# | Elapsed time: 18:7:3
#
# => Training Epoch #75, LR=0.0090
# | Epoch [ 75/ 95] Iter[391/391]		Loss: 1.5250 Acc@1: 69.598%-----------------Ensemble Model----------------------
# | Validation Epoch #75			Acc@1: 80.57%
# * General Top-1 Accuracy = 80.57%
# * General Top-5 Accuracy = 96.14%
# * Superclass Top-1 Accuracy = 88.20%
# * Superclass Top-5 Accuracy = 97.89%
# | Elapsed time: 18:21:49
#
# => Training Epoch #76, LR=0.0090
# | Epoch [ 76/ 95] Iter[391/391]		Loss: 0.0515 Acc@1: 71.496%-----------------Ensemble Model----------------------
# | Validation Epoch #76			Acc@1: 81.07%
# * General Top-1 Accuracy = 81.07%
# * General Top-5 Accuracy = 96.36%
# * Superclass Top-1 Accuracy = 88.81%
# * Superclass Top-5 Accuracy = 98.14%
# | Elapsed time: 18:36:57
#
# => Training Epoch #77, LR=0.0090
# | Epoch [ 77/ 95] Iter[391/391]		Loss: 1.7039 Acc@1: 70.642%-----------------Ensemble Model----------------------
# | Validation Epoch #77			Acc@1: 80.81%
# * General Top-1 Accuracy = 80.81%
# * General Top-5 Accuracy = 96.22%
# * Superclass Top-1 Accuracy = 88.90%
# * Superclass Top-5 Accuracy = 98.05%
# | Elapsed time: 18:51:56
#
# => Training Epoch #78, LR=0.0090
# | Epoch [ 78/ 95] Iter[391/391]		Loss: 1.7267 Acc@1: 69.884%-----------------Ensemble Model----------------------
# | Validation Epoch #78			Acc@1: 80.76%
# * General Top-1 Accuracy = 80.76%
# * General Top-5 Accuracy = 96.25%
# * Superclass Top-1 Accuracy = 88.91%
# * Superclass Top-5 Accuracy = 98.08%
# | Elapsed time: 19:6:44
#
# => Training Epoch #79, LR=0.0090
# | Epoch [ 79/ 95] Iter[391/391]		Loss: 0.3134 Acc@1: 71.378%-----------------Ensemble Model----------------------
# | Validation Epoch #79			Acc@1: 80.67%
# * General Top-1 Accuracy = 80.67%
# * General Top-5 Accuracy = 96.17%
# * Superclass Top-1 Accuracy = 88.40%
# * Superclass Top-5 Accuracy = 97.86%
# | Elapsed time: 19:21:30
#
# => Training Epoch #80, LR=0.0090
# | Epoch [ 80/ 95] Iter[391/391]		Loss: 1.2822 Acc@1: 70.082%-----------------Ensemble Model----------------------
# | Validation Epoch #80			Acc@1: 80.96%
# * General Top-1 Accuracy = 80.96%
# * General Top-5 Accuracy = 96.13%
# * Superclass Top-1 Accuracy = 88.57%
# * Superclass Top-5 Accuracy = 97.87%
# | Elapsed time: 19:36:17
#
# => Training Epoch #81, LR=0.0002
# | Epoch [ 81/ 95] Iter[391/391]		Loss: 1.4174 Acc@1: 70.668%-----------------Ensemble Model----------------------
# | Validation Epoch #81			Acc@1: 83.91%
# * General Top-1 Accuracy = 83.91%
# * General Top-5 Accuracy = 97.02%
# * Superclass Top-1 Accuracy = 90.84%
# * Superclass Top-5 Accuracy = 98.36%
# | Updating Best Top-1 model...			Acc@1 = 83.91%
# | Updating Best Top-5 model...			Acc@5 = 97.02%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 90.84%
# | Elapsed time: 19:51:16
#
# => Training Epoch #82, LR=0.0002
# | Epoch [ 82/ 95] Iter[391/391]		Loss: 1.3694 Acc@1: 74.674%-----------------Ensemble Model----------------------
# | Validation Epoch #82			Acc@1: 84.14%
# * General Top-1 Accuracy = 84.14%
# * General Top-5 Accuracy = 97.12%
# * Superclass Top-1 Accuracy = 90.87%
# * Superclass Top-5 Accuracy = 98.34%
# | Updating Best Top-1 model...			Acc@1 = 84.14%
# | Updating Best Top-5 model...			Acc@5 = 97.12%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 90.87%
# | Elapsed time: 20:6:18
#
# => Training Epoch #83, LR=0.0002
# | Epoch [ 83/ 95] Iter[391/391]		Loss: 1.4645 Acc@1: 76.682%-----------------Ensemble Model----------------------
# | Validation Epoch #83			Acc@1: 84.52%
# * General Top-1 Accuracy = 84.52%
# * General Top-5 Accuracy = 97.20%
# * Superclass Top-1 Accuracy = 91.30%
# * Superclass Top-5 Accuracy = 98.42%
# | Updating Best Top-1 model...			Acc@1 = 84.52%
# | Updating Best Top-5 model...			Acc@5 = 97.20%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 91.30%
# | Elapsed time: 20:21:21
#
# => Training Epoch #84, LR=0.0002
# | Epoch [ 84/ 95] Iter[391/391]		Loss: 1.0267 Acc@1: 73.808%-----------------Ensemble Model----------------------
# | Validation Epoch #84			Acc@1: 84.15%
# * General Top-1 Accuracy = 84.15%
# * General Top-5 Accuracy = 97.18%
# * Superclass Top-1 Accuracy = 90.94%
# * Superclass Top-5 Accuracy = 98.45%
# | Elapsed time: 20:35:59
#
# => Training Epoch #85, LR=0.0002
# | Epoch [ 85/ 95] Iter[391/391]		Loss: 1.0957 Acc@1: 75.256%-----------------Ensemble Model----------------------
# | Validation Epoch #85			Acc@1: 84.26%
# * General Top-1 Accuracy = 84.26%
# * General Top-5 Accuracy = 97.16%
# * Superclass Top-1 Accuracy = 90.96%
# * Superclass Top-5 Accuracy = 98.37%
# | Elapsed time: 20:50:50
#
# => Training Epoch #86, LR=0.0002
# | Epoch [ 86/ 95] Iter[391/391]		Loss: 1.2063 Acc@1: 74.938%-----------------Ensemble Model----------------------
# | Validation Epoch #86			Acc@1: 84.45%
# * General Top-1 Accuracy = 84.45%
# * General Top-5 Accuracy = 97.14%
# * Superclass Top-1 Accuracy = 91.22%
# * Superclass Top-5 Accuracy = 98.48%
# | Elapsed time: 21:5:42
#
# => Training Epoch #87, LR=0.0002
# | Epoch [ 87/ 95] Iter[391/391]		Loss: 1.1307 Acc@1: 73.748%-----------------Ensemble Model----------------------
# | Validation Epoch #87			Acc@1: 84.57%
# * General Top-1 Accuracy = 84.57%
# * General Top-5 Accuracy = 97.09%
# * Superclass Top-1 Accuracy = 91.16%
# * Superclass Top-5 Accuracy = 98.34%
# | Updating Best Top-1 model...			Acc@1 = 84.57%
# | Elapsed time: 21:20:34
#
# => Training Epoch #88, LR=0.0002
# | Epoch [ 88/ 95] Iter[391/391]		Loss: 0.4144 Acc@1: 74.152%-----------------Ensemble Model----------------------
# | Validation Epoch #88			Acc@1: 84.51%
# * General Top-1 Accuracy = 84.51%
# * General Top-5 Accuracy = 96.99%
# * Superclass Top-1 Accuracy = 91.19%
# * Superclass Top-5 Accuracy = 98.31%
# | Elapsed time: 21:35:18
#
# => Training Epoch #89, LR=0.0002
# | Epoch [ 89/ 95] Iter[391/391]		Loss: 0.9617 Acc@1: 76.046%-----------------Ensemble Model----------------------
# | Validation Epoch #89			Acc@1: 84.65%
# * General Top-1 Accuracy = 84.65%
# * General Top-5 Accuracy = 97.15%
# * Superclass Top-1 Accuracy = 91.33%
# * Superclass Top-5 Accuracy = 98.40%
# | Updating Best Top-1 model...			Acc@1 = 84.65%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 91.33%
# | Elapsed time: 21:50:5
#
# => Training Epoch #90, LR=0.0002
# | Epoch [ 90/ 95] Iter[391/391]		Loss: 1.5331 Acc@1: 73.142%-----------------Ensemble Model----------------------
# | Validation Epoch #90			Acc@1: 84.56%
# * General Top-1 Accuracy = 84.56%
# * General Top-5 Accuracy = 97.04%
# * Superclass Top-1 Accuracy = 91.20%
# * Superclass Top-5 Accuracy = 98.35%
# | Elapsed time: 22:4:56
#
# => Training Epoch #91, LR=0.0002
# | Epoch [ 91/ 95] Iter[391/391]		Loss: 0.9703 Acc@1: 75.800%-----------------Ensemble Model----------------------
# | Validation Epoch #91			Acc@1: 84.61%
# * General Top-1 Accuracy = 84.61%
# * General Top-5 Accuracy = 97.03%
# * Superclass Top-1 Accuracy = 91.22%
# * Superclass Top-5 Accuracy = 98.36%
# | Elapsed time: 22:19:39
#
# => Training Epoch #92, LR=0.0002
# | Epoch [ 92/ 95] Iter[391/391]		Loss: 1.0670 Acc@1: 74.208%-----------------Ensemble Model----------------------
# | Validation Epoch #92			Acc@1: 84.83%
# * General Top-1 Accuracy = 84.83%
# * General Top-5 Accuracy = 97.09%
# * Superclass Top-1 Accuracy = 91.43%
# * Superclass Top-5 Accuracy = 98.39%
# | Updating Best Top-1 model...			Acc@1 = 84.83%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 91.43%
# | Elapsed time: 22:34:16
#
# => Training Epoch #93, LR=0.0002
# | Epoch [ 93/ 95] Iter[391/391]		Loss: 0.9971 Acc@1: 74.838%-----------------Ensemble Model----------------------
# | Validation Epoch #93			Acc@1: 84.70%
# * General Top-1 Accuracy = 84.70%
# * General Top-5 Accuracy = 97.06%
# * Superclass Top-1 Accuracy = 91.40%
# * Superclass Top-5 Accuracy = 98.48%
# | Elapsed time: 22:48:51
#
# => Training Epoch #94, LR=0.0002
# | Epoch [ 94/ 95] Iter[391/391]		Loss: 0.9535 Acc@1: 71.854%-----------------Ensemble Model----------------------
# | Validation Epoch #94			Acc@1: 84.83%
# * General Top-1 Accuracy = 84.83%
# * General Top-5 Accuracy = 97.06%
# * Superclass Top-1 Accuracy = 91.33%
# * Superclass Top-5 Accuracy = 98.39%
# | Elapsed time: 23:3:27
#
# [Phase 4] : Testing model ensemble
# -----------------Ensemble Model----------------------
# | Validation Epoch #95			Acc@1: 84.83%
# * General Top-1 Accuracy = 84.83%
# * General Top-5 Accuracy = 97.06%
# * Superclass Top-1 Accuracy = 91.33%
# * Superclass Top-5 Accuracy = 98.39%
# * Final Test results : Best Acc@1 = 84.83%, Best Acc@5 = 97.20%, Best Superclass Acc@1 = 91.43%
