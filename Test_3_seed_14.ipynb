# %%
from __future__ import print_function
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import config as cf

import torchvision
import torchvision.transforms as transforms

import os
import sys
import time
import argparse
import datetime

from wide_resnet import *  # Wide_resnet.py
from torch.autograd import Variable
from torch.utils.data import ConcatDataset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import os

# %%
from __future__ import print_function
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import config as cf

import torchvision
import torchvision.transforms as transforms

import os
import sys
import time
import argparse
import datetime

from wide_resnet import *  # Wide_resnet.py
from torch.autograd import Variable
from torch.utils.data import ConcatDataset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import os

os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"
parser = argparse.ArgumentParser(description='PyTorch CIFAR-10 Training')
parser.add_argument('--lr', default=0.1, type=float, help='learning_rate')
parser.add_argument('--seed', default=27, type=int, help='seed')
parser.add_argument('--net_type', default='wide-resnet', type=str, help='model')
parser.add_argument('--depth', default=28, type=int, help='depth of model')
parser.add_argument('--widen_factor_1', default=14, type=int, help='width of model')
parser.add_argument('--widen_factor_2', default=16, type=int, help='width of model')
parser.add_argument('--widen_factor_3', default=18, type=int, help='width of model')
parser.add_argument('--dropout', default=0.2, type=float, help='dropout_rate')
parser.add_argument('--dataset', default='cifar100', type=str, help='dataset = cifar100')
parser.add_argument('--resume', '-r', action='store_true', help='resume from checkpoint')
parser.add_argument('--testOnly', '-t', action='store_true', help='Test mode with the saved model')
args = parser.parse_args(args=[])

# Seed setup
seed = args.seed
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True)

def map_to_superclass(labels, class_to_superclass):
    return [class_to_superclass[label] for label in labels]

def seed_worker(worker_id):
    np.random.seed(seed + worker_id)
    random.seed(seed + worker_id)

# Hyperparameter settings
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")
best_acc = 0
start_epoch, num_epochs, batch_size, optim_type = cf.start_epoch, cf.num_epochs, cf.batch_size, cf.optim_type

train_losses = []  # List to store training losses
test_losses = []   # List to store test losses

# Data Upload
print('\n[Phase 1] : Data Preparation')
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(cf.mean[args.dataset], cf.std[args.dataset]),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(cf.mean[args.dataset], cf.std[args.dataset]),
])

print("| Preparing CIFAR-100 dataset...")
sys.stdout.write("| ")
trainset = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR100(root='./data', train=False, download=False, transform=transform_test)
num_classes = 100

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=8, worker_init_fn=seed_worker)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False, num_workers=8)

# CIFAR-100 Superclass mapping (index-based)
superclass_mapping = {
    0: [4, 30, 55, 72, 95],  # aquatic mammals
    1: [1, 32, 67, 73, 91],  # fish
    2: [54, 62, 70, 82, 92],  # flowers
    3: [9, 10, 16, 28, 61],  # food containers
    4: [0, 51, 53, 57, 83],  # fruit and vegetables
    5: [22, 39, 40, 86, 87],  # household electrical devices
    6: [5, 20, 25, 84, 94],  # household furniture
    7: [6, 7, 14, 18, 24],   # insects
    8: [3, 42, 43, 88, 97],  # large carnivores
    9: [12, 17, 37, 68, 76],  # large man-made outdoor things
    10: [23, 33, 49, 60, 71],  # large natural outdoor scenes
    11: [15, 19, 21, 31, 38],  # large omnivores and herbivores
    12: [34, 63, 64, 66, 75],  # medium-sized mammals
    13: [26, 45, 77, 79, 99],  # non-insect invertebrates
    14: [2, 11, 35, 46, 98],  # people
    15: [27, 29, 44, 78, 93],  # reptiles
    16: [36, 50, 65, 74, 80],  # small mammals
    17: [47, 52, 56, 59, 96],  # trees
    18: [8, 13, 48, 58, 90],  # vehicles 1
    19: [41, 69, 81, 85, 89],  # vehicles 2
}

# Create a list to store which superclass each class belongs to
class_to_superclass = [None] * 100
for super_idx, class_indices in superclass_mapping.items():
    for class_idx in class_indices:
        class_to_superclass[class_idx] = super_idx

# CutMix function
def cutmix_data(x, y, beta=1.0):
    if beta > 0:
        lam = np.random.beta(beta, beta)
    else:
        lam = 1

    batch_size = x.size()[0]
    index = torch.randperm(batch_size).cuda()

    y_a, y_b = y, y[index]

    bbx1, bby1, bbx2, bby2 = rand_bbox(x.size(), lam)
    x[:, :, bbx1:bbx2, bby1:bby2] = x[index, :, bbx1:bbx2, bby1:bby2]

    lam = 1 - ((bbx2 - bbx1) * (bby2 - bby1) / (x.size()[-1] * x.size()[-2]))

    return x, y_a, y_b, lam

# Random box function for CutMix
def rand_bbox(size, lam):
    W = size[2]
    H = size[3]
    cut_rat = np.sqrt(1. - lam)
    cut_w = int(W * cut_rat)
    cut_h = int(H * cut_rat)

    cx = np.random.randint(W)
    cy = np.random.randint(H)

    bbx1 = np.clip(cx - cut_w // 2, 0, W)
    bby1 = np.clip(cy - cut_h // 2, 0, H)
    bbx2 = np.clip(cx + cut_w // 2, 0, W)
    bby2 = np.clip(cy + cut_h // 2, 0, H)

    return bbx1, bby1, bbx2, bby2

# Return Wide-ResNet network and filename
def get_ensemble_networks(args):
    net1 = Wide_ResNet(args.depth, args.widen_factor_1, args.dropout, num_classes)
    net2 = Wide_ResNet(args.depth, args.widen_factor_2, args.dropout, num_classes)
    net3 = Wide_ResNet(args.depth, args.widen_factor_3, args.dropout, num_classes)
    file_name1 = 'wide-resnet1-'+str(args.depth)+'x'+str(args.widen_factor_1)
    file_name2 = 'wide-resnet2-'+str(args.depth)+'x'+str(args.widen_factor_2)
    file_name3 = 'wide-resnet3-'+str(args.depth)+'x'+str(args.widen_factor_3)
    return [net1, net2, net3], [file_name1, file_name2, file_name3]


# Model setup
print('\n[Phase 2] : Model setup for Hard Voting Ensemble')
print('| Building net types for ensemble...')
nets, file_names = get_ensemble_networks(args)
for net in nets:
    net.apply(conv_init)

if use_cuda:
    for i, net in enumerate(nets):
        nets[i] = torch.nn.DataParallel(net, device_ids=range(torch.cuda.device_count()))
        nets[i].cuda()
    cudnn.benchmark = True

criterion = nn.CrossEntropyLoss()

# Hard Voting Prediction
def hard_voting_prediction(outputs_list):
    """Performs hard voting by choosing the most common prediction."""
    outputs_stack = torch.stack(outputs_list)  # Stack outputs from all models
    voted_predictions, _ = torch.mode(outputs_stack, dim=0)  # Hard voting
    return voted_predictions

# Training function
def train(epoch):

    optimizers = [optim.SGD(net.parameters(), lr=cf.learning_rate(args.lr, epoch), momentum=0.9, weight_decay=5e-4) for net in nets]

    for net in nets:
        net.train()

    train_loss = 0
    correct = 0
    total = 0

    print('\n=> Training Epoch #%d, LR=%.4f' %(epoch, cf.learning_rate(args.lr, epoch)))

    for batch_idx, (inputs, targets) in enumerate(trainloader):
        if use_cuda:
            inputs, targets = inputs.cuda(), targets.cuda()

        inputs, targets = Variable(inputs), Variable(targets)
        inputs, targets_a, targets_b, lam = cutmix_data(inputs, targets, beta=1.0)


        for i, net in enumerate(nets):
            optimizers[i].zero_grad()
            outputs = net(inputs)
            loss = lam * criterion(outputs, targets_a) + (1 - lam) * criterion(outputs, targets_b)
            loss.backward()
            optimizers[i].step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)
        correct += predicted.eq(targets.data).cpu().sum()

        sys.stdout.write('\r')
        sys.stdout.write('| Epoch [%3d/%3d] Iter[%3d/%3d]\t\tLoss: %.4f Acc@1: %.3f%%'
                         % (epoch, num_epochs, batch_idx+1,
                            (len(trainset)//batch_size)+1, loss.item(), 100.*correct/total))
        sys.stdout.flush()

    train_loss = train_loss / len(trainloader)
    train_losses.append(train_loss)

best_acc = 0
best_top5_acc = 0
best_superclass_top1_acc = 0

# Test function with hard voting ensemble
def test_ensemble(epoch):
    global best_acc, best_top5_acc, best_superclass_top1_acc
    for net in nets:
        net.eval()
    test_loss = 0
    correct = 0
    total = 0

    correct_top1_general = 0
    correct_top5_general = 0
    correct_top1_superclass = 0
    correct_top5_superclass = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            if use_cuda:
                inputs, targets = inputs.cuda(), targets.cuda()
            inputs, targets = Variable(inputs), Variable(targets)

            # Get outputs from all models
            outputs_list = [net(inputs) for net in nets]

            # Hard voting for Top-1 predictions
            outputs_avg = sum(outputs_list) / len(outputs_list)  # Average logits for top-5
            top5_pred = torch.topk(outputs_avg, 5, dim=1)[1]  # General top-5 prediction
            voted_top1 = hard_voting_prediction([torch.argmax(out, dim=1) for out in outputs_list])

            total += targets.size(0)
            correct += voted_top1.eq(targets.data).cpu().sum()

            correct_top1_general += voted_top1.eq(targets.data).cpu().sum()
            correct_top5_general += sum([targets[i] in top5_pred[i] for i in range(targets.size(0))])

            # Superclass accuracy
            true_superclass = torch.tensor(map_to_superclass(targets.cpu().numpy(), class_to_superclass)).to(device)
            pred_superclasses_top1 = torch.tensor(map_to_superclass(voted_top1.cpu().numpy(), class_to_superclass)).to(device)

            correct_top1_superclass += (pred_superclasses_top1 == true_superclass).sum().item()

            pred_superclasses_top5 = [torch.tensor(map_to_superclass(pred.cpu().numpy(), class_to_superclass)).to(device) for pred in top5_pred]
            for i in range(targets.size(0)):
                true_label_superclass = true_superclass[i].item()
                if true_label_superclass in pred_superclasses_top5[i].cpu().numpy():
                    correct_top5_superclass += 1

        # Test results output
        acc_top1_general = 100. * correct_top1_general / total
        acc_top5_general = 100. * correct_top5_general / total
        acc_top1_superclass = 100. * correct_top1_superclass / total
        acc_top5_superclass = 100. * correct_top5_superclass / total

        acc = 100.*correct/total
        print(f"-----------------Ensemble Model----------------------")
        print("| Validation Epoch #%d\t\t\tAcc@1: %.2f%%" %(epoch, acc))
        print(f"* General Top-1 Accuracy = {acc_top1_general:.2f}%")
        print(f"* General Top-5 Accuracy = {acc_top5_general:.2f}%")
        print(f"* Superclass Top-1 Accuracy = {acc_top1_superclass:.2f}%")
        print(f"* Superclass Top-5 Accuracy = {acc_top5_superclass:.2f}%")

        checkpoint_dir = './checkpoint/' + args.dataset + os.sep
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)

        # Save model if best accuracy is achieved for each metric
        if acc > best_acc:
            best_acc = acc
            print('| Updating Best Top-1 model...\t\t\tAcc@1 = %.2f%%' % (acc))
            torch.save({
                'net': nets,
                'acc': best_acc,
                'epoch': epoch,
            }, checkpoint_dir + 'best_top1_model.pth')

        if acc_top5_general > best_top5_acc:
            best_top5_acc = acc_top5_general
            print('| Updating Best Top-5 model...\t\t\tAcc@5 = %.2f%%' % (acc_top5_general))
            torch.save({
                'net': nets,
                'acc': best_top5_acc,
                'epoch': epoch,
            }, checkpoint_dir + 'best_top5_model.pth')

        if acc_top1_superclass > best_superclass_top1_acc:
            best_superclass_top1_acc = acc_top1_superclass
            print('| Updating Best Superclass Top-1 model...\t\t\tAcc@1 Superclass = %.2f%%' % (acc_top1_superclass))
            torch.save({
                'net': nets,
                'acc': best_superclass_top1_acc,
                'epoch': epoch,
            }, checkpoint_dir + 'best_superclass_top1_model.pth')

    return acc_top1_general, acc_top5_general, acc_top1_superclass, acc_top5_superclass

# Main training and testing loop
if not args.testOnly:
    elapsed_time = 0
    for epoch in range(start_epoch, num_epochs):
        start_time = time.time()

        train(epoch)
        test_ensemble(epoch)

        epoch_time = time.time() - start_time
        elapsed_time += epoch_time
        print(f'| Elapsed time: {int(elapsed_time//3600)}:{int((elapsed_time % 3600)//60)}:{int(elapsed_time % 60)}')

# Final testing with ensemble after all epochs
print('\n[Phase 4] : Testing model ensemble')
top1_acc, top5_acc, top1_superclass_acc, top5_superclass_acc = test_ensemble(cf.num_epochs)
print(f'* Final Test results : Best Acc@1 = {best_acc:.2f}%, Best Acc@5 = {best_top5_acc:.2f}%, Best Superclass Acc@1 = {best_superclass_top1_acc:.2f}%')

# Visualizing the training vs test loss
plt.plot(train_losses, label='Training Loss')
plt.plot(test_losses, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training vs Test Loss')
plt.show()
# Out:
# [Phase 1] : Data Preparation
# | Preparing CIFAR-100 dataset...
# | Files already downloaded and verified
#
# [Phase 2] : Model setup for Hard Voting Ensemble
# | Building net types for ensemble...
# | Wide-Resnet 28x14
# | Wide-Resnet 28x16
# | Wide-Resnet 28x18
#
# => Training Epoch #1, LR=0.1000
# | Epoch [  1/ 95] Iter[391/391]		Loss: 4.1911 Acc@1: 5.558%-----------------Ensemble Model----------------------
# | Validation Epoch #1			Acc@1: 10.68%
# * General Top-1 Accuracy = 10.68%
# * General Top-5 Accuracy = 33.31%
# * Superclass Top-1 Accuracy = 21.80%
# * Superclass Top-5 Accuracy = 54.39%
# | Updating Best Top-1 model...			Acc@1 = 10.68%
# | Updating Best Top-5 model...			Acc@5 = 33.31%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 21.80%
# | Elapsed time: 0:3:54
#
# => Training Epoch #2, LR=0.1000
# | Epoch [  2/ 95] Iter[391/391]		Loss: 3.3337 Acc@1: 9.302%-----------------Ensemble Model----------------------
# | Validation Epoch #2			Acc@1: 13.63%
# * General Top-1 Accuracy = 13.63%
# * General Top-5 Accuracy = 38.78%
# * Superclass Top-1 Accuracy = 26.57%
# * Superclass Top-5 Accuracy = 59.14%
# | Updating Best Top-1 model...			Acc@1 = 13.63%
# | Updating Best Top-5 model...			Acc@5 = 38.78%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 26.57%
# | Elapsed time: 0:7:39
#
# => Training Epoch #3, LR=0.1000
# | Epoch [  3/ 95] Iter[391/391]		Loss: 3.4638 Acc@1: 13.200%-----------------Ensemble Model----------------------
# | Validation Epoch #3			Acc@1: 18.53%
# * General Top-1 Accuracy = 18.53%
# * General Top-5 Accuracy = 44.66%
# * Superclass Top-1 Accuracy = 30.14%
# * Superclass Top-5 Accuracy = 60.82%
# | Updating Best Top-1 model...			Acc@1 = 18.53%
# | Updating Best Top-5 model...			Acc@5 = 44.66%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 30.14%
# | Elapsed time: 0:11:25
#
# => Training Epoch #4, LR=0.1000
# | Epoch [  4/ 95] Iter[391/391]		Loss: 3.5603 Acc@1: 16.954%-----------------Ensemble Model----------------------
# | Validation Epoch #4			Acc@1: 25.50%
# * General Top-1 Accuracy = 25.50%
# * General Top-5 Accuracy = 57.87%
# * Superclass Top-1 Accuracy = 39.33%
# * Superclass Top-5 Accuracy = 70.73%
# | Updating Best Top-1 model...			Acc@1 = 25.50%
# | Updating Best Top-5 model...			Acc@5 = 57.87%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 39.33%
# | Elapsed time: 0:15:8
#
# => Training Epoch #5, LR=0.1000
# | Epoch [  5/ 95] Iter[391/391]		Loss: 3.0915 Acc@1: 18.906%-----------------Ensemble Model----------------------
# | Validation Epoch #5			Acc@1: 20.73%
# * General Top-1 Accuracy = 20.73%
# * General Top-5 Accuracy = 48.88%
# * Superclass Top-1 Accuracy = 33.77%
# * Superclass Top-5 Accuracy = 63.74%
# | Elapsed time: 0:18:44
#
# => Training Epoch #6, LR=0.1000
# | Epoch [  6/ 95] Iter[391/391]		Loss: 2.3706 Acc@1: 22.588%-----------------Ensemble Model----------------------
# | Validation Epoch #6			Acc@1: 30.41%
# * General Top-1 Accuracy = 30.41%
# * General Top-5 Accuracy = 65.21%
# * Superclass Top-1 Accuracy = 46.07%
# * Superclass Top-5 Accuracy = 77.58%
# | Updating Best Top-1 model...			Acc@1 = 30.41%
# | Updating Best Top-5 model...			Acc@5 = 65.21%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 46.07%
# | Elapsed time: 0:22:27
#
# => Training Epoch #7, LR=0.1000
# | Epoch [  7/ 95] Iter[391/391]		Loss: 3.5236 Acc@1: 24.504%-----------------Ensemble Model----------------------
# | Validation Epoch #7			Acc@1: 31.85%
# * General Top-1 Accuracy = 31.85%
# * General Top-5 Accuracy = 63.28%
# * Superclass Top-1 Accuracy = 46.35%
# * Superclass Top-5 Accuracy = 74.29%
# | Updating Best Top-1 model...			Acc@1 = 31.85%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 46.35%
# | Elapsed time: 0:26:7
#
# => Training Epoch #8, LR=0.1000
# | Epoch [  8/ 95] Iter[391/391]		Loss: 3.4867 Acc@1: 26.312%-----------------Ensemble Model----------------------
# | Validation Epoch #8			Acc@1: 31.78%
# * General Top-1 Accuracy = 31.78%
# * General Top-5 Accuracy = 68.03%
# * Superclass Top-1 Accuracy = 46.90%
# * Superclass Top-5 Accuracy = 80.35%
# | Updating Best Top-5 model...			Acc@5 = 68.03%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 46.90%
# | Elapsed time: 0:29:48
#
# => Training Epoch #9, LR=0.1000
# | Epoch [  9/ 95] Iter[391/391]		Loss: 2.1850 Acc@1: 28.382%-----------------Ensemble Model----------------------
# | Validation Epoch #9			Acc@1: 38.60%
# * General Top-1 Accuracy = 38.60%
# * General Top-5 Accuracy = 72.56%
# * Superclass Top-1 Accuracy = 53.03%
# * Superclass Top-5 Accuracy = 82.70%
# | Updating Best Top-1 model...			Acc@1 = 38.60%
# | Updating Best Top-5 model...			Acc@5 = 72.56%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 53.03%
# | Elapsed time: 0:33:37
#
# => Training Epoch #10, LR=0.1000
# | Epoch [ 10/ 95] Iter[391/391]		Loss: 2.9012 Acc@1: 29.372%-----------------Ensemble Model----------------------
# | Validation Epoch #10			Acc@1: 34.11%
# * General Top-1 Accuracy = 34.11%
# * General Top-5 Accuracy = 66.79%
# * Superclass Top-1 Accuracy = 47.83%
# * Superclass Top-5 Accuracy = 78.77%
# | Elapsed time: 0:37:13
#
# => Training Epoch #11, LR=0.1000
# | Epoch [ 11/ 95] Iter[391/391]		Loss: 2.2106 Acc@1: 32.178%-----------------Ensemble Model----------------------
# | Validation Epoch #11			Acc@1: 33.23%
# * General Top-1 Accuracy = 33.23%
# * General Top-5 Accuracy = 65.23%
# * Superclass Top-1 Accuracy = 46.25%
# * Superclass Top-5 Accuracy = 77.36%
# | Elapsed time: 0:40:48
#
# => Training Epoch #12, LR=0.1000
# | Epoch [ 12/ 95] Iter[391/391]		Loss: 3.3450 Acc@1: 32.218%-----------------Ensemble Model----------------------
# | Validation Epoch #12			Acc@1: 38.75%
# * General Top-1 Accuracy = 38.75%
# * General Top-5 Accuracy = 74.52%
# * Superclass Top-1 Accuracy = 53.70%
# * Superclass Top-5 Accuracy = 84.65%
# | Updating Best Top-1 model...			Acc@1 = 38.75%
# | Updating Best Top-5 model...			Acc@5 = 74.52%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 53.70%
# | Elapsed time: 0:44:35
#
# => Training Epoch #13, LR=0.1000
# | Epoch [ 13/ 95] Iter[391/391]		Loss: 3.3814 Acc@1: 33.946%-----------------Ensemble Model----------------------
# | Validation Epoch #13			Acc@1: 44.07%
# * General Top-1 Accuracy = 44.07%
# * General Top-5 Accuracy = 78.99%
# * Superclass Top-1 Accuracy = 58.76%
# * Superclass Top-5 Accuracy = 88.17%
# | Updating Best Top-1 model...			Acc@1 = 44.07%
# | Updating Best Top-5 model...			Acc@5 = 78.99%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 58.76%
# | Elapsed time: 0:48:17
#
# => Training Epoch #14, LR=0.1000
# | Epoch [ 14/ 95] Iter[391/391]		Loss: 1.9108 Acc@1: 34.472%-----------------Ensemble Model----------------------
# | Validation Epoch #14			Acc@1: 47.08%
# * General Top-1 Accuracy = 47.08%
# * General Top-5 Accuracy = 79.45%
# * Superclass Top-1 Accuracy = 59.72%
# * Superclass Top-5 Accuracy = 87.84%
# | Updating Best Top-1 model...			Acc@1 = 47.08%
# | Updating Best Top-5 model...			Acc@5 = 79.45%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 59.72%
# | Elapsed time: 0:52:1
#
# => Training Epoch #15, LR=0.1000
# | Epoch [ 15/ 95] Iter[391/391]		Loss: 2.1924 Acc@1: 34.904%-----------------Ensemble Model----------------------
# | Validation Epoch #15			Acc@1: 47.32%
# * General Top-1 Accuracy = 47.32%
# * General Top-5 Accuracy = 81.00%
# * Superclass Top-1 Accuracy = 61.44%
# * Superclass Top-5 Accuracy = 88.53%
# | Updating Best Top-1 model...			Acc@1 = 47.32%
# | Updating Best Top-5 model...			Acc@5 = 81.00%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 61.44%
# | Elapsed time: 0:55:43
#
# => Training Epoch #16, LR=0.1000
# | Epoch [ 16/ 95] Iter[391/391]		Loss: 3.4452 Acc@1: 36.666%-----------------Ensemble Model----------------------
# | Validation Epoch #16			Acc@1: 51.12%
# * General Top-1 Accuracy = 51.12%
# * General Top-5 Accuracy = 82.92%
# * Superclass Top-1 Accuracy = 64.47%
# * Superclass Top-5 Accuracy = 90.41%
# | Updating Best Top-1 model...			Acc@1 = 51.12%
# | Updating Best Top-5 model...			Acc@5 = 82.92%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 64.47%
# | Elapsed time: 0:59:25
#
# => Training Epoch #17, LR=0.1000
# | Epoch [ 17/ 95] Iter[391/391]		Loss: 3.2626 Acc@1: 38.842%-----------------Ensemble Model----------------------
# | Validation Epoch #17			Acc@1: 49.90%
# * General Top-1 Accuracy = 49.90%
# * General Top-5 Accuracy = 81.93%
# * Superclass Top-1 Accuracy = 64.38%
# * Superclass Top-5 Accuracy = 89.57%
# | Elapsed time: 1:3:1
#
# => Training Epoch #18, LR=0.1000
# | Epoch [ 18/ 95] Iter[391/391]		Loss: 3.1902 Acc@1: 37.346%-----------------Ensemble Model----------------------
# | Validation Epoch #18			Acc@1: 50.65%
# * General Top-1 Accuracy = 50.65%
# * General Top-5 Accuracy = 83.36%
# * Superclass Top-1 Accuracy = 66.59%
# * Superclass Top-5 Accuracy = 90.63%
# | Updating Best Top-5 model...			Acc@5 = 83.36%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 66.59%
# | Elapsed time: 1:6:41
#
# => Training Epoch #19, LR=0.1000
# | Epoch [ 19/ 95] Iter[391/391]		Loss: 2.7131 Acc@1: 39.610%-----------------Ensemble Model----------------------
# | Validation Epoch #19			Acc@1: 53.16%
# * General Top-1 Accuracy = 53.16%
# * General Top-5 Accuracy = 84.63%
# * Superclass Top-1 Accuracy = 66.56%
# * Superclass Top-5 Accuracy = 90.67%
# | Updating Best Top-1 model...			Acc@1 = 53.16%
# | Updating Best Top-5 model...			Acc@5 = 84.63%
# | Elapsed time: 1:10:21
#
# => Training Epoch #20, LR=0.1000
# | Epoch [ 20/ 95] Iter[391/391]		Loss: 3.0828 Acc@1: 39.916%-----------------Ensemble Model----------------------
# | Validation Epoch #20			Acc@1: 55.30%
# * General Top-1 Accuracy = 55.30%
# * General Top-5 Accuracy = 85.61%
# * Superclass Top-1 Accuracy = 67.15%
# * Superclass Top-5 Accuracy = 91.52%
# | Updating Best Top-1 model...			Acc@1 = 55.30%
# | Updating Best Top-5 model...			Acc@5 = 85.61%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 67.15%
# | Elapsed time: 1:14:7
#
# => Training Epoch #21, LR=0.1000
# | Epoch [ 21/ 95] Iter[391/391]		Loss: 2.7301 Acc@1: 39.556%-----------------Ensemble Model----------------------
# | Validation Epoch #21			Acc@1: 54.31%
# * General Top-1 Accuracy = 54.31%
# * General Top-5 Accuracy = 83.14%
# * Superclass Top-1 Accuracy = 66.39%
# * Superclass Top-5 Accuracy = 89.82%
# | Elapsed time: 1:17:42
#
# => Training Epoch #22, LR=0.1000
# | Epoch [ 22/ 95] Iter[391/391]		Loss: 1.4977 Acc@1: 40.936%-----------------Ensemble Model----------------------
# | Validation Epoch #22			Acc@1: 56.97%
# * General Top-1 Accuracy = 56.97%
# * General Top-5 Accuracy = 85.55%
# * Superclass Top-1 Accuracy = 68.52%
# * Superclass Top-5 Accuracy = 90.26%
# | Updating Best Top-1 model...			Acc@1 = 56.97%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 68.52%
# | Elapsed time: 1:21:22
#
# => Training Epoch #23, LR=0.1000
# | Epoch [ 23/ 95] Iter[391/391]		Loss: 2.6256 Acc@1: 41.972%-----------------Ensemble Model----------------------
# | Validation Epoch #23			Acc@1: 55.77%
# * General Top-1 Accuracy = 55.77%
# * General Top-5 Accuracy = 84.51%
# * Superclass Top-1 Accuracy = 68.43%
# * Superclass Top-5 Accuracy = 90.95%
# | Elapsed time: 1:24:58
#
# => Training Epoch #24, LR=0.1000
# | Epoch [ 24/ 95] Iter[391/391]		Loss: 2.8558 Acc@1: 42.912%-----------------Ensemble Model----------------------
# | Validation Epoch #24			Acc@1: 54.87%
# * General Top-1 Accuracy = 54.87%
# * General Top-5 Accuracy = 84.44%
# * Superclass Top-1 Accuracy = 67.74%
# * Superclass Top-5 Accuracy = 90.86%
# | Elapsed time: 1:28:34
#
# => Training Epoch #25, LR=0.1000
# | Epoch [ 25/ 95] Iter[391/391]		Loss: 2.8219 Acc@1: 42.734%-----------------Ensemble Model----------------------
# | Validation Epoch #25			Acc@1: 58.06%
# * General Top-1 Accuracy = 58.06%
# * General Top-5 Accuracy = 87.57%
# * Superclass Top-1 Accuracy = 71.06%
# * Superclass Top-5 Accuracy = 93.14%
# | Updating Best Top-1 model...			Acc@1 = 58.06%
# | Updating Best Top-5 model...			Acc@5 = 87.57%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 71.06%
# | Elapsed time: 1:32:18
#
# => Training Epoch #26, LR=0.1000
# | Epoch [ 26/ 95] Iter[391/391]		Loss: 3.0087 Acc@1: 44.228%-----------------Ensemble Model----------------------
# | Validation Epoch #26			Acc@1: 54.78%
# * General Top-1 Accuracy = 54.78%
# * General Top-5 Accuracy = 84.83%
# * Superclass Top-1 Accuracy = 67.03%
# * Superclass Top-5 Accuracy = 91.47%
# | Elapsed time: 1:35:53
#
# => Training Epoch #27, LR=0.1000
# | Epoch [ 27/ 95] Iter[391/391]		Loss: 3.0739 Acc@1: 42.868%-----------------Ensemble Model----------------------
# | Validation Epoch #27			Acc@1: 50.99%
# * General Top-1 Accuracy = 50.99%
# * General Top-5 Accuracy = 80.85%
# * Superclass Top-1 Accuracy = 62.43%
# * Superclass Top-5 Accuracy = 87.42%
# | Elapsed time: 1:39:29
#
# => Training Epoch #28, LR=0.1000
# | Epoch [ 28/ 95] Iter[391/391]		Loss: 2.0629 Acc@1: 44.066%-----------------Ensemble Model----------------------
# | Validation Epoch #28			Acc@1: 58.62%
# * General Top-1 Accuracy = 58.62%
# * General Top-5 Accuracy = 87.00%
# * Superclass Top-1 Accuracy = 71.05%
# * Superclass Top-5 Accuracy = 92.70%
# | Updating Best Top-1 model...			Acc@1 = 58.62%
# | Elapsed time: 1:43:7
#
# => Training Epoch #29, LR=0.1000
# | Epoch [ 29/ 95] Iter[391/391]		Loss: 2.9759 Acc@1: 43.132%-----------------Ensemble Model----------------------
# | Validation Epoch #29			Acc@1: 56.92%
# * General Top-1 Accuracy = 56.92%
# * General Top-5 Accuracy = 85.63%
# * Superclass Top-1 Accuracy = 68.42%
# * Superclass Top-5 Accuracy = 91.36%
# | Elapsed time: 1:46:43
#
# => Training Epoch #30, LR=0.1000
# | Epoch [ 30/ 95] Iter[391/391]		Loss: 2.0098 Acc@1: 43.984%-----------------Ensemble Model----------------------
# | Validation Epoch #30			Acc@1: 57.42%
# * General Top-1 Accuracy = 57.42%
# * General Top-5 Accuracy = 87.42%
# * Superclass Top-1 Accuracy = 69.13%
# * Superclass Top-5 Accuracy = 92.89%
# | Elapsed time: 1:50:19
#
# => Training Epoch #31, LR=0.0300
# | Epoch [ 31/ 95] Iter[391/391]		Loss: 2.8808 Acc@1: 52.560%-----------------Ensemble Model----------------------
# | Validation Epoch #31			Acc@1: 71.89%
# * General Top-1 Accuracy = 71.89%
# * General Top-5 Accuracy = 93.47%
# * Superclass Top-1 Accuracy = 82.95%
# * Superclass Top-5 Accuracy = 96.41%
# | Updating Best Top-1 model...			Acc@1 = 71.89%
# | Updating Best Top-5 model...			Acc@5 = 93.47%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 82.95%
# | Elapsed time: 1:54:6
#
# => Training Epoch #32, LR=0.0300
# | Epoch [ 32/ 95] Iter[391/391]		Loss: 2.2189 Acc@1: 54.392%-----------------Ensemble Model----------------------
# | Validation Epoch #32			Acc@1: 72.13%
# * General Top-1 Accuracy = 72.13%
# * General Top-5 Accuracy = 93.66%
# * Superclass Top-1 Accuracy = 83.30%
# * Superclass Top-5 Accuracy = 96.59%
# | Updating Best Top-1 model...			Acc@1 = 72.13%
# | Updating Best Top-5 model...			Acc@5 = 93.66%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 83.30%
# | Elapsed time: 1:57:52
#
# => Training Epoch #33, LR=0.0300
# | Epoch [ 33/ 95] Iter[391/391]		Loss: 2.4290 Acc@1: 55.768%-----------------Ensemble Model----------------------
# | Validation Epoch #33			Acc@1: 72.91%
# * General Top-1 Accuracy = 72.91%
# * General Top-5 Accuracy = 93.90%
# * Superclass Top-1 Accuracy = 83.40%
# * Superclass Top-5 Accuracy = 96.33%
# | Updating Best Top-1 model...			Acc@1 = 72.91%
# | Updating Best Top-5 model...			Acc@5 = 93.90%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 83.40%
# | Elapsed time: 2:1:38
#
# => Training Epoch #34, LR=0.0300
# | Epoch [ 34/ 95] Iter[391/391]		Loss: 2.5734 Acc@1: 57.596%-----------------Ensemble Model----------------------
# | Validation Epoch #34			Acc@1: 72.47%
# * General Top-1 Accuracy = 72.47%
# * General Top-5 Accuracy = 93.83%
# * Superclass Top-1 Accuracy = 83.25%
# * Superclass Top-5 Accuracy = 96.52%
# | Elapsed time: 2:5:14
#
# => Training Epoch #35, LR=0.0300
# | Epoch [ 35/ 95] Iter[391/391]		Loss: 2.6049 Acc@1: 56.142%-----------------Ensemble Model----------------------
# | Validation Epoch #35			Acc@1: 73.21%
# * General Top-1 Accuracy = 73.21%
# * General Top-5 Accuracy = 93.91%
# * Superclass Top-1 Accuracy = 82.90%
# * Superclass Top-5 Accuracy = 96.35%
# | Updating Best Top-1 model...			Acc@1 = 73.21%
# | Updating Best Top-5 model...			Acc@5 = 93.91%
# | Elapsed time: 2:8:55
#
# => Training Epoch #36, LR=0.0300
# | Epoch [ 36/ 95] Iter[391/391]		Loss: 2.3300 Acc@1: 56.692%-----------------Ensemble Model----------------------
# | Validation Epoch #36			Acc@1: 73.13%
# * General Top-1 Accuracy = 73.13%
# * General Top-5 Accuracy = 93.93%
# * Superclass Top-1 Accuracy = 83.91%
# * Superclass Top-5 Accuracy = 96.68%
# | Updating Best Top-5 model...			Acc@5 = 93.93%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 83.91%
# | Elapsed time: 2:12:35
#
# => Training Epoch #37, LR=0.0300
# | Epoch [ 37/ 95] Iter[391/391]		Loss: 2.3370 Acc@1: 55.800%-----------------Ensemble Model----------------------
# | Validation Epoch #37			Acc@1: 71.16%
# * General Top-1 Accuracy = 71.16%
# * General Top-5 Accuracy = 93.27%
# * Superclass Top-1 Accuracy = 81.56%
# * Superclass Top-5 Accuracy = 96.23%
# | Elapsed time: 2:16:11
#
# => Training Epoch #38, LR=0.0300
# | Epoch [ 38/ 95] Iter[391/391]		Loss: 1.4791 Acc@1: 56.768%-----------------Ensemble Model----------------------
# | Validation Epoch #38			Acc@1: 73.74%
# * General Top-1 Accuracy = 73.74%
# * General Top-5 Accuracy = 94.23%
# * Superclass Top-1 Accuracy = 83.96%
# * Superclass Top-5 Accuracy = 97.01%
# | Updating Best Top-1 model...			Acc@1 = 73.74%
# | Updating Best Top-5 model...			Acc@5 = 94.23%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 83.96%
# | Elapsed time: 2:19:55
#
# => Training Epoch #39, LR=0.0300
# | Epoch [ 39/ 95] Iter[391/391]		Loss: 1.2739 Acc@1: 56.964%-----------------Ensemble Model----------------------
# | Validation Epoch #39			Acc@1: 72.82%
# * General Top-1 Accuracy = 72.82%
# * General Top-5 Accuracy = 93.45%
# * Superclass Top-1 Accuracy = 82.53%
# * Superclass Top-5 Accuracy = 96.50%
# | Elapsed time: 2:23:31
#
# => Training Epoch #40, LR=0.0300
# | Epoch [ 40/ 95] Iter[391/391]		Loss: 2.4133 Acc@1: 57.646%-----------------Ensemble Model----------------------
# | Validation Epoch #40			Acc@1: 74.33%
# * General Top-1 Accuracy = 74.33%
# * General Top-5 Accuracy = 94.53%
# * Superclass Top-1 Accuracy = 83.74%
# * Superclass Top-5 Accuracy = 97.12%
# | Updating Best Top-1 model...			Acc@1 = 74.33%
# | Updating Best Top-5 model...			Acc@5 = 94.53%
# | Elapsed time: 2:27:11
#
# => Training Epoch #41, LR=0.0300
# | Epoch [ 41/ 95] Iter[391/391]		Loss: 1.8277 Acc@1: 56.330%-----------------Ensemble Model----------------------
# | Validation Epoch #41			Acc@1: 72.49%
# * General Top-1 Accuracy = 72.49%
# * General Top-5 Accuracy = 94.06%
# * Superclass Top-1 Accuracy = 82.86%
# * Superclass Top-5 Accuracy = 96.71%
# | Elapsed time: 2:30:47
#
# => Training Epoch #42, LR=0.0300
# | Epoch [ 42/ 95] Iter[391/391]		Loss: 1.8248 Acc@1: 58.694%-----------------Ensemble Model----------------------
# | Validation Epoch #42			Acc@1: 72.48%
# * General Top-1 Accuracy = 72.48%
# * General Top-5 Accuracy = 93.40%
# * Superclass Top-1 Accuracy = 82.21%
# * Superclass Top-5 Accuracy = 96.22%
# | Elapsed time: 2:34:23
#
# => Training Epoch #43, LR=0.0300
# | Epoch [ 43/ 95] Iter[391/391]		Loss: 2.4248 Acc@1: 56.248%-----------------Ensemble Model----------------------
# | Validation Epoch #43			Acc@1: 71.71%
# * General Top-1 Accuracy = 71.71%
# * General Top-5 Accuracy = 93.26%
# * Superclass Top-1 Accuracy = 81.94%
# * Superclass Top-5 Accuracy = 95.88%
# | Elapsed time: 2:37:59
#
# => Training Epoch #44, LR=0.0300
# | Epoch [ 44/ 95] Iter[391/391]		Loss: 2.5563 Acc@1: 58.602%-----------------Ensemble Model----------------------
# | Validation Epoch #44			Acc@1: 74.76%
# * General Top-1 Accuracy = 74.76%
# * General Top-5 Accuracy = 94.44%
# * Superclass Top-1 Accuracy = 84.20%
# * Superclass Top-5 Accuracy = 96.92%
# | Updating Best Top-1 model...			Acc@1 = 74.76%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 84.20%
# | Elapsed time: 2:41:39
#
# => Training Epoch #45, LR=0.0300
# | Epoch [ 45/ 95] Iter[391/391]		Loss: 1.7733 Acc@1: 56.674%-----------------Ensemble Model----------------------
# | Validation Epoch #45			Acc@1: 72.49%
# * General Top-1 Accuracy = 72.49%
# * General Top-5 Accuracy = 94.21%
# * Superclass Top-1 Accuracy = 83.40%
# * Superclass Top-5 Accuracy = 96.74%
# | Elapsed time: 2:45:15
#
# => Training Epoch #46, LR=0.0300
# | Epoch [ 46/ 95] Iter[391/391]		Loss: 1.9002 Acc@1: 59.136%-----------------Ensemble Model----------------------
# | Validation Epoch #46			Acc@1: 74.17%
# * General Top-1 Accuracy = 74.17%
# * General Top-5 Accuracy = 94.35%
# * Superclass Top-1 Accuracy = 83.85%
# * Superclass Top-5 Accuracy = 96.82%
# | Elapsed time: 2:48:51
#
# => Training Epoch #47, LR=0.0300
# | Epoch [ 47/ 95] Iter[391/391]		Loss: 1.9617 Acc@1: 57.356%-----------------Ensemble Model----------------------
# | Validation Epoch #47			Acc@1: 74.42%
# * General Top-1 Accuracy = 74.42%
# * General Top-5 Accuracy = 94.24%
# * Superclass Top-1 Accuracy = 84.10%
# * Superclass Top-5 Accuracy = 96.67%
# | Elapsed time: 2:52:27
#
# => Training Epoch #48, LR=0.0300
# | Epoch [ 48/ 95] Iter[391/391]		Loss: 1.8366 Acc@1: 59.264%-----------------Ensemble Model----------------------
# | Validation Epoch #48			Acc@1: 74.05%
# * General Top-1 Accuracy = 74.05%
# * General Top-5 Accuracy = 94.31%
# * Superclass Top-1 Accuracy = 84.03%
# * Superclass Top-5 Accuracy = 96.86%
# | Elapsed time: 2:56:3
#
# => Training Epoch #49, LR=0.0300
# | Epoch [ 49/ 95] Iter[391/391]		Loss: 2.1855 Acc@1: 58.244%-----------------Ensemble Model----------------------
# | Validation Epoch #49			Acc@1: 75.05%
# * General Top-1 Accuracy = 75.05%
# * General Top-5 Accuracy = 94.52%
# * Superclass Top-1 Accuracy = 84.47%
# * Superclass Top-5 Accuracy = 96.81%
# | Updating Best Top-1 model...			Acc@1 = 75.05%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 84.47%
# | Elapsed time: 2:59:43
#
# => Training Epoch #50, LR=0.0300
# | Epoch [ 50/ 95] Iter[391/391]		Loss: 2.4172 Acc@1: 60.050%-----------------Ensemble Model----------------------
# | Validation Epoch #50			Acc@1: 74.25%
# * General Top-1 Accuracy = 74.25%
# * General Top-5 Accuracy = 94.70%
# * Superclass Top-1 Accuracy = 84.00%
# * Superclass Top-5 Accuracy = 97.09%
# | Updating Best Top-5 model...			Acc@5 = 94.70%
# | Elapsed time: 3:3:22
#
# => Training Epoch #51, LR=0.0300
# | Epoch [ 51/ 95] Iter[391/391]		Loss: 2.3976 Acc@1: 59.496%-----------------Ensemble Model----------------------
# | Validation Epoch #51			Acc@1: 74.50%
# * General Top-1 Accuracy = 74.50%
# * General Top-5 Accuracy = 94.34%
# * Superclass Top-1 Accuracy = 84.22%
# * Superclass Top-5 Accuracy = 96.81%
# | Elapsed time: 3:6:58
#
# => Training Epoch #52, LR=0.0300
# | Epoch [ 52/ 95] Iter[391/391]		Loss: 2.2502 Acc@1: 58.522%-----------------Ensemble Model----------------------
# | Validation Epoch #52			Acc@1: 75.02%
# * General Top-1 Accuracy = 75.02%
# * General Top-5 Accuracy = 94.81%
# * Superclass Top-1 Accuracy = 84.54%
# * Superclass Top-5 Accuracy = 97.20%
# | Updating Best Top-5 model...			Acc@5 = 94.81%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 84.54%
# | Elapsed time: 3:10:38
#
# => Training Epoch #53, LR=0.0300
# | Epoch [ 53/ 95] Iter[391/391]		Loss: 1.4262 Acc@1: 58.916%-----------------Ensemble Model----------------------
# | Validation Epoch #53			Acc@1: 75.09%
# * General Top-1 Accuracy = 75.09%
# * General Top-5 Accuracy = 94.78%
# * Superclass Top-1 Accuracy = 84.63%
# * Superclass Top-5 Accuracy = 97.26%
# | Updating Best Top-1 model...			Acc@1 = 75.09%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 84.63%
# | Elapsed time: 3:14:18
#
# => Training Epoch #54, LR=0.0300
# | Epoch [ 54/ 95] Iter[391/391]		Loss: 2.2024 Acc@1: 59.690%-----------------Ensemble Model----------------------
# | Validation Epoch #54			Acc@1: 73.96%
# * General Top-1 Accuracy = 73.96%
# * General Top-5 Accuracy = 94.71%
# * Superclass Top-1 Accuracy = 84.01%
# * Superclass Top-5 Accuracy = 97.03%
# | Elapsed time: 3:17:55
#
# => Training Epoch #55, LR=0.0300
# | Epoch [ 55/ 95] Iter[391/391]		Loss: 2.0406 Acc@1: 59.048%-----------------Ensemble Model----------------------
# | Validation Epoch #55			Acc@1: 75.10%
# * General Top-1 Accuracy = 75.10%
# * General Top-5 Accuracy = 94.76%
# * Superclass Top-1 Accuracy = 83.89%
# * Superclass Top-5 Accuracy = 97.18%
# | Updating Best Top-1 model...			Acc@1 = 75.10%
# | Elapsed time: 3:21:33
#
# => Training Epoch #56, LR=0.0300
# | Epoch [ 56/ 95] Iter[391/391]		Loss: 2.2660 Acc@1: 60.232%-----------------Ensemble Model----------------------
# | Validation Epoch #56			Acc@1: 73.05%
# * General Top-1 Accuracy = 73.05%
# * General Top-5 Accuracy = 94.49%
# * Superclass Top-1 Accuracy = 83.46%
# * Superclass Top-5 Accuracy = 97.09%
# | Elapsed time: 3:25:10
#
# => Training Epoch #57, LR=0.0300
# | Epoch [ 57/ 95] Iter[391/391]		Loss: 1.6326 Acc@1: 59.682%-----------------Ensemble Model----------------------
# | Validation Epoch #57			Acc@1: 74.88%
# * General Top-1 Accuracy = 74.88%
# * General Top-5 Accuracy = 94.50%
# * Superclass Top-1 Accuracy = 84.49%
# * Superclass Top-5 Accuracy = 96.86%
# | Elapsed time: 3:28:45
#
# => Training Epoch #58, LR=0.0300
# | Epoch [ 58/ 95] Iter[391/391]		Loss: 1.7480 Acc@1: 58.780%-----------------Ensemble Model----------------------
# | Validation Epoch #58			Acc@1: 75.63%
# * General Top-1 Accuracy = 75.63%
# * General Top-5 Accuracy = 94.98%
# * Superclass Top-1 Accuracy = 85.23%
# * Superclass Top-5 Accuracy = 97.00%
# | Updating Best Top-1 model...			Acc@1 = 75.63%
# | Updating Best Top-5 model...			Acc@5 = 94.98%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 85.23%
# | Elapsed time: 3:32:28
#
# => Training Epoch #59, LR=0.0300
# | Epoch [ 59/ 95] Iter[391/391]		Loss: 1.9512 Acc@1: 61.022%-----------------Ensemble Model----------------------
# | Validation Epoch #59			Acc@1: 75.53%
# * General Top-1 Accuracy = 75.53%
# * General Top-5 Accuracy = 94.84%
# * Superclass Top-1 Accuracy = 84.61%
# * Superclass Top-5 Accuracy = 97.09%
# | Elapsed time: 3:36:4
#
# => Training Epoch #60, LR=0.0300
# | Epoch [ 60/ 95] Iter[391/391]		Loss: 1.6694 Acc@1: 59.342%-----------------Ensemble Model----------------------
# | Validation Epoch #60			Acc@1: 74.31%
# * General Top-1 Accuracy = 74.31%
# * General Top-5 Accuracy = 94.28%
# * Superclass Top-1 Accuracy = 83.09%
# * Superclass Top-5 Accuracy = 96.60%
# | Elapsed time: 3:39:40
#
# => Training Epoch #61, LR=0.0090
# | Epoch [ 61/ 95] Iter[391/391]		Loss: 1.3841 Acc@1: 66.654%-----------------Ensemble Model----------------------
# | Validation Epoch #61			Acc@1: 81.73%
# * General Top-1 Accuracy = 81.73%
# * General Top-5 Accuracy = 96.86%
# * Superclass Top-1 Accuracy = 89.42%
# * Superclass Top-5 Accuracy = 98.23%
# | Updating Best Top-1 model...			Acc@1 = 81.73%
# | Updating Best Top-5 model...			Acc@5 = 96.86%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 89.42%
# | Elapsed time: 3:43:25
#
# => Training Epoch #62, LR=0.0090
# | Epoch [ 62/ 95] Iter[391/391]		Loss: 1.6271 Acc@1: 67.914%-----------------Ensemble Model----------------------
# | Validation Epoch #62			Acc@1: 81.69%
# * General Top-1 Accuracy = 81.69%
# * General Top-5 Accuracy = 96.55%
# * Superclass Top-1 Accuracy = 89.35%
# * Superclass Top-5 Accuracy = 98.03%
# | Elapsed time: 3:47:0
#
# => Training Epoch #63, LR=0.0090
# | Epoch [ 63/ 95] Iter[391/391]		Loss: 1.3731 Acc@1: 67.620%-----------------Ensemble Model----------------------
# | Validation Epoch #63			Acc@1: 81.91%
# * General Top-1 Accuracy = 81.91%
# * General Top-5 Accuracy = 96.59%
# * Superclass Top-1 Accuracy = 89.39%
# * Superclass Top-5 Accuracy = 98.19%
# | Updating Best Top-1 model...			Acc@1 = 81.91%
# | Elapsed time: 3:50:39
#
# => Training Epoch #64, LR=0.0090
# | Epoch [ 64/ 95] Iter[391/391]		Loss: 1.5662 Acc@1: 69.440%-----------------Ensemble Model----------------------
# | Validation Epoch #64			Acc@1: 81.69%
# * General Top-1 Accuracy = 81.69%
# * General Top-5 Accuracy = 96.45%
# * Superclass Top-1 Accuracy = 89.39%
# * Superclass Top-5 Accuracy = 98.10%
# | Elapsed time: 3:54:15
#
# => Training Epoch #65, LR=0.0090
# | Epoch [ 65/ 95] Iter[391/391]		Loss: 1.7364 Acc@1: 71.018%-----------------Ensemble Model----------------------
# | Validation Epoch #65			Acc@1: 82.01%
# * General Top-1 Accuracy = 82.01%
# * General Top-5 Accuracy = 96.61%
# * Superclass Top-1 Accuracy = 89.48%
# * Superclass Top-5 Accuracy = 98.10%
# | Updating Best Top-1 model...			Acc@1 = 82.01%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 89.48%
# | Elapsed time: 3:57:55
#
# => Training Epoch #66, LR=0.0090
# | Epoch [ 66/ 95] Iter[391/391]		Loss: 1.5768 Acc@1: 67.324%-----------------Ensemble Model----------------------
# | Validation Epoch #66			Acc@1: 81.48%
# * General Top-1 Accuracy = 81.48%
# * General Top-5 Accuracy = 96.57%
# * Superclass Top-1 Accuracy = 89.51%
# * Superclass Top-5 Accuracy = 98.29%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 89.51%
# | Elapsed time: 4:1:33
#
# => Training Epoch #67, LR=0.0090
# | Epoch [ 67/ 95] Iter[391/391]		Loss: 0.4679 Acc@1: 68.542%-----------------Ensemble Model----------------------
# | Validation Epoch #67			Acc@1: 81.70%
# * General Top-1 Accuracy = 81.70%
# * General Top-5 Accuracy = 96.55%
# * Superclass Top-1 Accuracy = 89.57%
# * Superclass Top-5 Accuracy = 98.21%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 89.57%
# | Elapsed time: 4:5:11
#
# => Training Epoch #68, LR=0.0090
# | Epoch [ 68/ 95] Iter[391/391]		Loss: 0.5662 Acc@1: 70.978%-----------------Ensemble Model----------------------
# | Validation Epoch #68			Acc@1: 81.34%
# * General Top-1 Accuracy = 81.34%
# * General Top-5 Accuracy = 96.28%
# * Superclass Top-1 Accuracy = 89.14%
# * Superclass Top-5 Accuracy = 97.99%
# | Elapsed time: 4:8:47
#
# => Training Epoch #69, LR=0.0090
# | Epoch [ 69/ 95] Iter[391/391]		Loss: 1.3132 Acc@1: 72.310%-----------------Ensemble Model----------------------
# | Validation Epoch #69			Acc@1: 81.78%
# * General Top-1 Accuracy = 81.78%
# * General Top-5 Accuracy = 96.33%
# * Superclass Top-1 Accuracy = 89.26%
# * Superclass Top-5 Accuracy = 98.16%
# | Elapsed time: 4:12:23
#
# => Training Epoch #70, LR=0.0090
# | Epoch [ 70/ 95] Iter[391/391]		Loss: 0.1464 Acc@1: 73.438%-----------------Ensemble Model----------------------
# | Validation Epoch #70			Acc@1: 81.45%
# * General Top-1 Accuracy = 81.45%
# * General Top-5 Accuracy = 96.36%
# * Superclass Top-1 Accuracy = 89.14%
# * Superclass Top-5 Accuracy = 97.93%
# | Elapsed time: 4:16:0
#
# => Training Epoch #71, LR=0.0090
# | Epoch [ 71/ 95] Iter[391/391]		Loss: 1.5388 Acc@1: 68.748%-----------------Ensemble Model----------------------
# | Validation Epoch #71			Acc@1: 81.59%
# * General Top-1 Accuracy = 81.59%
# * General Top-5 Accuracy = 96.19%
# * Superclass Top-1 Accuracy = 89.19%
# * Superclass Top-5 Accuracy = 98.19%
# | Elapsed time: 4:19:36
#
# => Training Epoch #72, LR=0.0090
# | Epoch [ 72/ 95] Iter[391/391]		Loss: 1.5845 Acc@1: 69.974%-----------------Ensemble Model----------------------
# | Validation Epoch #72			Acc@1: 81.91%
# * General Top-1 Accuracy = 81.91%
# * General Top-5 Accuracy = 96.51%
# * Superclass Top-1 Accuracy = 89.59%
# * Superclass Top-5 Accuracy = 98.02%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 89.59%
# | Elapsed time: 4:23:14
#
# => Training Epoch #73, LR=0.0090
# | Epoch [ 73/ 95] Iter[391/391]		Loss: 1.7146 Acc@1: 72.182%-----------------Ensemble Model----------------------
# | Validation Epoch #73			Acc@1: 81.64%
# * General Top-1 Accuracy = 81.64%
# * General Top-5 Accuracy = 96.28%
# * Superclass Top-1 Accuracy = 89.35%
# * Superclass Top-5 Accuracy = 97.99%
# | Elapsed time: 4:26:50
#
# => Training Epoch #74, LR=0.0090
# | Epoch [ 74/ 95] Iter[391/391]		Loss: 1.7104 Acc@1: 70.664%-----------------Ensemble Model----------------------
# | Validation Epoch #74			Acc@1: 81.45%
# * General Top-1 Accuracy = 81.45%
# * General Top-5 Accuracy = 96.39%
# * Superclass Top-1 Accuracy = 89.36%
# * Superclass Top-5 Accuracy = 98.19%
# | Elapsed time: 4:30:27
#
# => Training Epoch #75, LR=0.0090
# | Epoch [ 75/ 95] Iter[391/391]		Loss: 1.6301 Acc@1: 68.184%-----------------Ensemble Model----------------------
# | Validation Epoch #75			Acc@1: 80.97%
# * General Top-1 Accuracy = 80.97%
# * General Top-5 Accuracy = 96.31%
# * Superclass Top-1 Accuracy = 88.92%
# * Superclass Top-5 Accuracy = 97.97%
# | Elapsed time: 4:34:3
#
# => Training Epoch #76, LR=0.0090
# | Epoch [ 76/ 95] Iter[391/391]		Loss: 1.1561 Acc@1: 71.374%-----------------Ensemble Model----------------------
# | Validation Epoch #76			Acc@1: 81.24%
# * General Top-1 Accuracy = 81.24%
# * General Top-5 Accuracy = 96.57%
# * Superclass Top-1 Accuracy = 89.21%
# * Superclass Top-5 Accuracy = 98.21%
# | Elapsed time: 4:37:39
#
# => Training Epoch #77, LR=0.0090
# | Epoch [ 77/ 95] Iter[391/391]		Loss: 1.4475 Acc@1: 69.470%-----------------Ensemble Model----------------------
# | Validation Epoch #77			Acc@1: 81.54%
# * General Top-1 Accuracy = 81.54%
# * General Top-5 Accuracy = 96.16%
# * Superclass Top-1 Accuracy = 89.33%
# * Superclass Top-5 Accuracy = 98.07%
# | Elapsed time: 4:41:15
#
# => Training Epoch #78, LR=0.0090
# | Epoch [ 78/ 95] Iter[391/391]		Loss: 2.0305 Acc@1: 72.950%-----------------Ensemble Model----------------------
# | Validation Epoch #78			Acc@1: 80.92%
# * General Top-1 Accuracy = 80.92%
# * General Top-5 Accuracy = 96.23%
# * Superclass Top-1 Accuracy = 89.20%
# * Superclass Top-5 Accuracy = 98.10%
# | Elapsed time: 4:44:51
#
# => Training Epoch #79, LR=0.0090
# | Epoch [ 79/ 95] Iter[391/391]		Loss: 1.8003 Acc@1: 70.646%-----------------Ensemble Model----------------------
# | Validation Epoch #79			Acc@1: 80.59%
# * General Top-1 Accuracy = 80.59%
# * General Top-5 Accuracy = 95.93%
# * Superclass Top-1 Accuracy = 88.73%
# * Superclass Top-5 Accuracy = 97.79%
# | Elapsed time: 4:48:27
#
# => Training Epoch #80, LR=0.0090
# | Epoch [ 80/ 95] Iter[391/391]		Loss: 1.5620 Acc@1: 68.844%-----------------Ensemble Model----------------------
# | Validation Epoch #80			Acc@1: 81.28%
# * General Top-1 Accuracy = 81.28%
# * General Top-5 Accuracy = 96.42%
# * Superclass Top-1 Accuracy = 89.42%
# * Superclass Top-5 Accuracy = 98.00%
# | Elapsed time: 4:52:3
#
# => Training Epoch #81, LR=0.0002
# | Epoch [ 81/ 95] Iter[391/391]		Loss: 1.0340 Acc@1: 71.960%-----------------Ensemble Model----------------------
# | Validation Epoch #81			Acc@1: 83.51%
# * General Top-1 Accuracy = 83.51%
# * General Top-5 Accuracy = 96.76%
# * Superclass Top-1 Accuracy = 90.68%
# * Superclass Top-5 Accuracy = 98.31%
# | Updating Best Top-1 model...			Acc@1 = 83.51%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 90.68%
# | Elapsed time: 4:55:46
#
# => Training Epoch #82, LR=0.0002
# | Epoch [ 82/ 95] Iter[391/391]		Loss: 0.8173 Acc@1: 77.488%-----------------Ensemble Model----------------------
# | Validation Epoch #82			Acc@1: 84.07%
# * General Top-1 Accuracy = 84.07%
# * General Top-5 Accuracy = 96.87%
# * Superclass Top-1 Accuracy = 91.15%
# * Superclass Top-5 Accuracy = 98.44%
# | Updating Best Top-1 model...			Acc@1 = 84.07%
# | Updating Best Top-5 model...			Acc@5 = 96.87%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 91.15%
# | Elapsed time: 4:59:28
#
# => Training Epoch #83, LR=0.0002
# | Epoch [ 83/ 95] Iter[391/391]		Loss: 1.4198 Acc@1: 73.532%-----------------Ensemble Model----------------------
# | Validation Epoch #83			Acc@1: 84.07%
# * General Top-1 Accuracy = 84.07%
# * General Top-5 Accuracy = 96.87%
# * Superclass Top-1 Accuracy = 90.96%
# * Superclass Top-5 Accuracy = 98.50%
# | Elapsed time: 5:3:4
#
# => Training Epoch #84, LR=0.0002
# | Epoch [ 84/ 95] Iter[391/391]		Loss: 0.7157 Acc@1: 74.608%-----------------Ensemble Model----------------------
# | Validation Epoch #84			Acc@1: 84.39%
# * General Top-1 Accuracy = 84.39%
# * General Top-5 Accuracy = 96.97%
# * Superclass Top-1 Accuracy = 91.26%
# * Superclass Top-5 Accuracy = 98.45%
# | Updating Best Top-1 model...			Acc@1 = 84.39%
# | Updating Best Top-5 model...			Acc@5 = 96.97%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 91.26%
# | Elapsed time: 5:6:51
#
# => Training Epoch #85, LR=0.0002
# | Epoch [ 85/ 95] Iter[391/391]		Loss: 1.4117 Acc@1: 75.004%-----------------Ensemble Model----------------------
# | Validation Epoch #85			Acc@1: 84.40%
# * General Top-1 Accuracy = 84.40%
# * General Top-5 Accuracy = 96.94%
# * Superclass Top-1 Accuracy = 91.21%
# * Superclass Top-5 Accuracy = 98.50%
# | Updating Best Top-1 model...			Acc@1 = 84.40%
# | Elapsed time: 5:10:29
#
# => Training Epoch #86, LR=0.0002
# | Epoch [ 86/ 95] Iter[391/391]		Loss: 0.3397 Acc@1: 77.018%-----------------Ensemble Model----------------------
# | Validation Epoch #86			Acc@1: 84.45%
# * General Top-1 Accuracy = 84.45%
# * General Top-5 Accuracy = 96.92%
# * Superclass Top-1 Accuracy = 91.29%
# * Superclass Top-5 Accuracy = 98.47%
# | Updating Best Top-1 model...			Acc@1 = 84.45%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 91.29%
# | Elapsed time: 5:14:9
#
# => Training Epoch #87, LR=0.0002
# | Epoch [ 87/ 95] Iter[391/391]		Loss: 0.9828 Acc@1: 76.154%-----------------Ensemble Model----------------------
# | Validation Epoch #87			Acc@1: 84.23%
# * General Top-1 Accuracy = 84.23%
# * General Top-5 Accuracy = 96.86%
# * Superclass Top-1 Accuracy = 91.09%
# * Superclass Top-5 Accuracy = 98.55%
# | Elapsed time: 5:17:45
#
# => Training Epoch #88, LR=0.0002
# | Epoch [ 88/ 95] Iter[391/391]		Loss: 1.2162 Acc@1: 74.934%-----------------Ensemble Model----------------------
# | Validation Epoch #88			Acc@1: 84.53%
# * General Top-1 Accuracy = 84.53%
# * General Top-5 Accuracy = 96.94%
# * Superclass Top-1 Accuracy = 91.38%
# * Superclass Top-5 Accuracy = 98.51%
# | Updating Best Top-1 model...			Acc@1 = 84.53%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 91.38%
# | Elapsed time: 5:21:25
#
# => Training Epoch #89, LR=0.0002
# | Epoch [ 89/ 95] Iter[391/391]		Loss: 1.3076 Acc@1: 72.508%-----------------Ensemble Model----------------------
# | Validation Epoch #89			Acc@1: 84.42%
# * General Top-1 Accuracy = 84.42%
# * General Top-5 Accuracy = 96.97%
# * Superclass Top-1 Accuracy = 91.47%
# * Superclass Top-5 Accuracy = 98.52%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 91.47%
# | Elapsed time: 5:25:3
#
# => Training Epoch #90, LR=0.0002
# | Epoch [ 90/ 95] Iter[391/391]		Loss: 1.1416 Acc@1: 73.930%-----------------Ensemble Model----------------------
# | Validation Epoch #90			Acc@1: 84.61%
# * General Top-1 Accuracy = 84.61%
# * General Top-5 Accuracy = 96.93%
# * Superclass Top-1 Accuracy = 91.47%
# * Superclass Top-5 Accuracy = 98.54%
# | Updating Best Top-1 model...			Acc@1 = 84.61%
# | Elapsed time: 5:28:41
#
# => Training Epoch #91, LR=0.0002
# | Epoch [ 91/ 95] Iter[391/391]		Loss: 1.0851 Acc@1: 76.142%-----------------Ensemble Model----------------------
# | Validation Epoch #91			Acc@1: 84.52%
# * General Top-1 Accuracy = 84.52%
# * General Top-5 Accuracy = 96.92%
# * Superclass Top-1 Accuracy = 91.39%
# * Superclass Top-5 Accuracy = 98.63%
# | Elapsed time: 5:32:18
#
# => Training Epoch #92, LR=0.0002
# | Epoch [ 92/ 95] Iter[391/391]		Loss: 1.3161 Acc@1: 73.620%-----------------Ensemble Model----------------------
# | Validation Epoch #92			Acc@1: 84.63%
# * General Top-1 Accuracy = 84.63%
# * General Top-5 Accuracy = 96.94%
# * Superclass Top-1 Accuracy = 91.51%
# * Superclass Top-5 Accuracy = 98.62%
# | Updating Best Top-1 model...			Acc@1 = 84.63%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 91.51%
# | Elapsed time: 5:35:58
#
# => Training Epoch #93, LR=0.0002
# | Epoch [ 93/ 95] Iter[391/391]		Loss: 0.9485 Acc@1: 75.548%-----------------Ensemble Model----------------------
# | Validation Epoch #93			Acc@1: 84.65%
# * General Top-1 Accuracy = 84.65%
# * General Top-5 Accuracy = 97.05%
# * Superclass Top-1 Accuracy = 91.60%
# * Superclass Top-5 Accuracy = 98.59%
# | Updating Best Top-1 model...			Acc@1 = 84.65%
# | Updating Best Top-5 model...			Acc@5 = 97.05%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 91.60%
# | Elapsed time: 5:39:40
#
# => Training Epoch #94, LR=0.0002
# | Epoch [ 94/ 95] Iter[391/391]		Loss: 1.1982 Acc@1: 72.784%-----------------Ensemble Model----------------------
# | Validation Epoch #94			Acc@1: 84.63%
# * General Top-1 Accuracy = 84.63%
# * General Top-5 Accuracy = 96.84%
# * Superclass Top-1 Accuracy = 91.64%
# * Superclass Top-5 Accuracy = 98.41%
# | Updating Best Superclass Top-1 model...			Acc@1 Superclass = 91.64%
# | Elapsed time: 5:43:18
#
# [Phase 4] : Testing model ensemble
# -----------------Ensemble Model----------------------
# | Validation Epoch #95			Acc@1: 84.63%
# * General Top-1 Accuracy = 84.63%
# * General Top-5 Accuracy = 96.84%
# * Superclass Top-1 Accuracy = 91.64%
# * Superclass Top-5 Accuracy = 98.41%
# * Final Test results : Best Acc@1 = 84.65%, Best Acc@5 = 97.05%, Best Superclass Acc@1 = 91.64%

# %%
#Top-1, Top-5
# | Epoch [ 93/ 95] Iter[391/391]		Loss: 0.9485 Acc@1: 75.548%-----------------Ensemble Model----------------------
# | Validation Epoch #93			Acc@1: 84.65%
# * General Top-1 Accuracy = 84.65%
# * General Top-5 Accuracy = 97.05%
# * Superclass Top-1 Accuracy = 91.60%

273.3

# %%
#SuperClass
# | Epoch [ 94/ 95] Iter[391/391]		Loss: 1.1982 Acc@1: 72.784%-----------------Ensemble Model----------------------
# | Validation Epoch #94			Acc@1: 84.63%
# * General Top-1 Accuracy = 84.63%
# * General Top-5 Accuracy = 96.84%
# * Superclass Top-1 Accuracy = 91.64%

273.11
